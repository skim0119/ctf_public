# %% [markdown]
# # Capture the Flag (RL - Policy Gradient)
#
# - Seung Hyun Kim
# - skim449@illinois.edu
#
# ## Notes
# - This notebook includes:
#     - Building the structure of policy driven network.
#     - Training with/without render
#     - Saver that save model and weights to ./model directory
#     - Writer that will record some necessary datas to ./logs
# - This notebook does not include running the CtF game with the RL policy. Using the network will be separately scripted in policy/policy_RL1.py.
#     - cap_test.py is changed appropriately.
#
# ## References :
# - https://github.com/awjuliani/DeepRL-Agents/blob/master/Vanilla-Policy.ipynb (source)
# - https://www.youtube.com/watch?v=PDbXPBwOavc

# %%
import os

import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.layers as layers
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt
# %matplotlib inline

import time
import gym
import gym_cap
import gym_cap.envs.const as CONST
import numpy as np
import random

# the modules that you can use to generate the policy.
import policy.patrol 
import policy.random
import policy.simple # custon written policy
import policy.policy_RL
import policy.zeros

# Data Processing Module
from DataModule import one_hot_encoder, VISION_dX, VISION_dY
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Hyperparameters

# %%
TRAIN_NAME='NO_RED_07_criticQ'
LOG_PATH='./logs/'+TRAIN_NAME
MODEL_PATH='./model/' + TRAIN_NAME
GPU_CAPACITY=0.3 # gpu capacity in percentage

# %%
# Training Related
total_episodes = 20000 #Set total number of episodes to train agent on.
max_ep = 300
update_frequency = 10
batch_size = 500
experience_size=50000

# Model Related
LEARNING_RATE = 1e-5

# Saving Related
save_network_frequency = 100
save_stat_frequency = 50
moving_average_step = 50

# %% [markdown]
# ## Environment Setting

# %%
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)
    
#Create a directory to save episode playback gifs to
if not os.path.exists(LOG_PATH):
    os.makedirs(LOG_PATH)

# %%
env = gym.make("cap-v0") # initialize the environment
policy_red = policy.random.PolicyGen(env.get_map, env.get_team_red)
action_space = len(env.ACTION)
n_agent = len(env.get_team_blue)

print('red number : ', len(env.get_team_red))
print('blue number : ', len(env.get_team_blue))
# Out:
# red number :  0
# blue number :  4

# %% [markdown]
# ## Discount Reward

# %%
gamma = 0.98

def discount_rewards(r, base=0):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0.0
    for t in reversed(range(r.size)):
        running_add = (running_add * gamma + r[t])
        discounted_r[t] = running_add
    #discounted_r = (discounted_r - np.mean(discounted_r)) / (np.std(discounted_r)+1e-8) # normalize
    return discounted_r - base

# %% [markdown]
# ## Network Setting

# %%
class AgentDQN():
    def __init__(self, lr, in_size,action_size):
        self.state_input = tf.placeholder(shape=in_size,dtype=tf.float32, name='state')
        layer = slim.conv2d(self.state_input, 16, [5,5], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv1')
        layer = slim.conv2d(layer, 16, [3,3], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv2')
        #layer = slim.flatten(layer)
        adv_stream, val_stream = tf.split(layer, num_or_size_splits=2, axis=3)
        
        # Advantage stream
        adv = slim.flatten(adv_stream)
        adv = slim.fully_connected(adv, action_size,
                                    weights_initializer=layers.xavier_initializer(),
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=tf.zeros_initializer())
        # Value stream
        val = slim.flatten(val_stream)
        val = slim.fully_connected(val, 1,
                                    weights_initializer=layers.xavier_initializer(),
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=tf.zeros_initializer())
        
        # Merge two stream to get Q
        self.evalQ = val + tf.subtract(adv, tf.reduce_mean(adv, axis=1, keepdims=True))
        self.output = tf.nn.softmax(self.evalQ, name='action')
        self.predict = tf.argmax(self.evalQ,1)
                                
        tf.summary.histogram('output', self.output)
        tf.summary.histogram('evalQ', self.evalQ)
        for var in slim.get_model_variables():
            tf.summary.histogram(var.op.name, var)
            
        #Below we obtain the loss by taking the sum of squares difference between the target and prediction Q values.
        self.targetQ = tf.placeholder(shape=[None],dtype=tf.float32)
        self.actions = tf.placeholder(shape=[None],dtype=tf.int32)
        self.actions_onehot = tf.one_hot(self.actions,action_size,dtype=tf.float32)
        
        self.Q = tf.reduce_sum(tf.multiply(self.evalQ, self.actions_onehot), axis=1)
        
        self.loss = tf.reduce_mean(tf.square(self.targetQ - self.Q))
        self.trainer = tf.train.AdamOptimizer(learning_rate=lr)
        self.update_batch = self.trainer.minimize(self.loss)

# %%
class TargetDQN():
    def __init__(self, lr, in_size,action_size):
        self.state_input = tf.placeholder(shape=in_size,dtype=tf.float32)
        layer = slim.conv2d(self.state_input, 16, [5,5], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME')
        layer = slim.conv2d(layer, 16, [3,3], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME')
        #layer = slim.flatten(layer)
        adv_stream, val_stream = tf.split(layer, num_or_size_splits=2, axis=3)
        
        # Advantage stream
        adv = slim.flatten(adv_stream)
        self.adv = slim.fully_connected(adv, action_size,
                                    weights_initializer=layers.xavier_initializer(),
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=tf.zeros_initializer())
        # Value stream
        val = slim.flatten(val_stream)
        self.val = slim.fully_connected(val, 1,
                                    weights_initializer=layers.xavier_initializer(),
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=tf.zeros_initializer())
        
        # Merge two stream to get Q
        self.evalQ = self.val + tf.subtract(self.adv, tf.reduce_mean(self.adv, axis=1, keepdims=True))
        self.output = tf.nn.softmax(self.evalQ)
        self.predict = tf.argmax(self.evalQ,1)

# %%
tf.reset_default_graph() # Clear the Tensorflow graph.
myAgent = AgentDQN(lr=LEARNING_RATE,in_size=[None,VISION_dX,VISION_dY,6],action_size=5) #Load the agent.
targetAgent = TargetDQN(lr=LEARNING_RATE,in_size=[None,VISION_dX,VISION_dY,6],action_size=5)
global_step = tf.Variable(0, trainable=False, name='global_step') # global step
increment_global_step_op = tf.assign(global_step, global_step+1)
merged = tf.summary.merge_all()

# %% [markdown]
# ## Session

# %%
# Launch the session
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=GPU_CAPACITY, allow_growth=True)

sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
#sess = tf.Session()

total_reward = []
total_length = []
total_captured = []
total_loss=[]

# Setup Save and Restore Network
saver = tf.train.Saver(tf.global_variables())
writer = tf.summary.FileWriter(LOG_PATH, sess.graph)

ckpt = tf.train.get_checkpoint_state(MODEL_PATH)
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("Load Model : ", ckpt.model_checkpoint_path)
else:
    sess.run(tf.global_variables_initializer())
    print("Initialized Variables")
# Out:
# Initialized Variables

# %%
def record(obs):
    with tf.device('/cpu:0'): 
        summary = tf.Summary()
        summary.value.add(tag='Records/mean_reward', simple_value=np.mean(total_reward[-moving_average_step:]))
        summary.value.add(tag='Records/mean_length', simple_value=np.mean(total_length[-moving_average_step:]))
        summary.value.add(tag='Records/mean_succeed', simple_value=np.mean(total_captured[-moving_average_step:]))
        summary.value.add(tag='Loss', simple_value=np.mean(total_loss[-moving_average_step:]))
        writer.add_summary(summary, sess.run(global_step))
        
        summary_str = sess.run(merged,feed_dict={myAgent.state_input:obs})
        writer.add_summary(summary_str, sess.run(global_step))
        
        writer.flush()

# %%
class Experience_buffer():
    def __init__(self, buffer_size = experience_size):
        self.buffer = []
        self.buffer_size = buffer_size
    
    def add(self,experience):
        if len(self.buffer) + len(experience) >= self.buffer_size:
            self.buffer[0:(len(experience)+len(self.buffer))-self.buffer_size] = []
        self.buffer.extend(experience)
    
    def flush(self):
        self.buffer = []
        self.buffer_size = 0
    
    def sample(self, size):
        if size > len(self.buffer):
            return np.array(self.buffer)
        else:
            return np.reshape(np.array(random.sample(self.buffer,size)),[size,5])

# %%
def policy_rollout(env):
    # Run single episode, return the results (number of frame, history, total reward, game_won, last obs)
    s = env.reset(map_size=20, policy_red=policy_red)
    #obs = one_hot_encoder(s, env.get_team_blue).tolist() # partial observation
    obs_post = one_hot_encoder(env._env, env.get_team_blue) # Full observation
    
    ep_history = []
    indv_history = [[] for _ in range(len(env.get_team_blue))]
    
    was_alive = [ag.isAlive for ag in env.get_team_blue]
    prev_reward=0
    for frame in range(max_ep+1):
        obs = obs_post
        
        with tf.device('/cpu:0'):        
            #Probabilistically pick an action given our network outputs.
            act_prob = sess.run(myAgent.output, feed_dict={myAgent.state_input:obs})
            act = [np.random.choice(action_space, p=act_prob[x]/sum(act_prob[x])) for x in range(n_agent)] # divide by sum : normalize
            
        s,r,d,_ = env.step(act) #Get our reward for taking an action given a bandit.
        obs_post = one_hot_encoder(env._env, env.get_team_blue) # Full observation
        #obs_post = one_hot_encoder(s, env.get_team_blue).tolist() # partial observation
        
        # If frame is at max and the game is still not done, negative reward
        if frame == max_ep and d == False:
            r -= 30
            
        # Push history for individual that 'was' alive previous frame
        for idx, agent in enumerate(env.get_team_blue):
            if was_alive[idx]: indv_history[idx].append([obs[idx],act[idx],r,obs_post[idx],d])

        # If reward sequence change, push the history into the episode history.
        if prev_reward != r:
            for idx, history in enumerate(indv_history):
                if len(history)==0: continue
                if not was_alive[idx]: continue
                _history = np.array(history)
                _history[:,2] = discount_rewards(_history[:,2])
                ep_history.extend(_history)
        
        # State Transition
        frame += 1
        prev_reward = r
        was_alive = [ag.isAlive for ag in env.get_team_blue]
        
        if d == True:
            break
    if len(ep_history) > 0:        
        ep_history = np.stack(ep_history)
    
    return [frame, ep_history, r, env.game_won, obs]

# %% [markdown]
# ## Training

# %%
def updateTargetGraph(tfVars,tau):
    total_vars = len(tfVars)
    op_holder = []
    for idx,var in enumerate(tfVars[0:total_vars//2]):
        op_holder.append(tfVars[idx+total_vars//2].assign((var.value()*tau) + ((1-tau)*tfVars[idx+total_vars//2].value())))
    return op_holder

def updateTarget(op_holder):
    for op in op_holder:
        sess.run(op)

# %%
if __name__=='__main__':
    ep = 0
    tau = 0.01
    trainables = tf.trainable_variables()
    targetOps = updateTargetGraph(trainables,tau)

    myBuffer = Experience_buffer()
    
    try:
        progbar = tf.keras.utils.Progbar(total_episodes,width=5)
        while ep < total_episodes+1:
            progbar.update(ep) # update progress bar
            
            # Run episode
            frame, history, reward, did_won, obs = policy_rollout(env)
            
            # Add history
            myBuffer.add(history)
            if ep % update_frequency == 0 and ep != 0:
                with tf.device('/gpu:0'):
                    batch_history = myBuffer.sample(batch_size) # Sample from experience replay
                    Q1 = sess.run(myAgent.predict,feed_dict={myAgent.state_input:np.stack(batch_history[:,3])})
                    Q2 = sess.run(targetAgent.evalQ,feed_dict={targetAgent.state_input:np.stack(batch_history[:,3])})
                    end_multiplier = -(batch_history[:,4] - 1)
                    doubleQ = Q2[range(batch_size),Q1]
                    targetQ = batch_history[:,2] + (gamma*doubleQ * end_multiplier)
                    #Update the network with our target values.
                    loss,_ = sess.run([myAgent.loss, myAgent.update_batch], feed_dict={myAgent.state_input:np.stack(batch_history[:,0]),
                                                                                       myAgent.targetQ:targetQ,
                                                                                       myAgent.actions:batch_history[:,1]})
                    total_loss.append(loss)
                    updateTarget(targetOps) #Update the target network toward the primary network.
            
            total_reward.append(reward)
            total_length.append(frame)
            total_captured.append(env.game_won)
            
            if ep % save_stat_frequency == 0 and ep != 0:
                record(obs)

            # save every 100 ep
            if ep % save_network_frequency == 0 and ep != 0:
                print(' Average r : ', np.mean(total_reward[-save_network_frequency:]))
                saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
                print("save weights: ", sess.run(global_step), 'episodes')

            ep += 1
            sess.run(increment_global_step_op)

    except KeyboardInterrupt:
        print('\n\nManually stopped the training (KeyboardInterrupt)');
        plt.plot(total_reward)
        plt.figure()
        plt.plot(total_length)
        plt.figure()
        plt.plot(total_captured)
        saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
        record(obs)
        print("save: ", sess.run(global_step), 'episodes')
# Out:
#   100/20000 [.....] - ETA: 10:05:57 Average r :  7.7
# save weights:  100 episodes
#   200/20000 [.....] - ETA: 9:41:48 Average r :  18.1
# save weights:  200 episodes
#   300/20000 [.....] - ETA: 9:56:13 Average r :  2.5
# save weights:  300 episodes
#   400/20000 [.....] - ETA: 9:55:37 Average r :  7.7
# save weights:  400 episodes
#   500/20000 [.....] - ETA: 9:49:21 Average r :  15.5
# save weights:  500 episodes
#   600/20000 [.....] - ETA: 9:50:35 Average r :  7.7
# save weights:  600 episodes
#   700/20000 [.....] - ETA: 9:47:10 Average r :  12.9
# save weights:  700 episodes
#   800/20000 [.....] - ETA: 9:43:05 Average r :  16.8
# save weights:  800 episodes
#   900/20000 [.....] - ETA: 9:41:53 Average r :  6.4
# save weights:  900 episodes
#  1000/20000 [.....] - ETA: 9:37:17 Average r :  11.6
# save weights:  1000 episodes
#  1100/20000 [.....] - ETA: 9:36:15 Average r :  7.7
# save weights:  1100 episodes
#  1200/20000 [.....] - ETA: 9:35:10 Average r :  9.0
# save weights:  1200 episodes
#  1300/20000 [.....] - ETA: 9:32:46 Average r :  9.0
# save weights:  1300 episodes
#  1400/20000 [.....] - ETA: 9:28:09 Average r :  22.0
# save weights:  1400 episodes
#  1500/20000 [.....] - ETA: 9:24:53 Average r :  15.5
# save weights:  1500 episodes
#  1600/20000 [.....] - ETA: 9:23:30 Average r :  2.5
# save weights:  1600 episodes
#  1700/20000 [.....] - ETA: 9:21:08 Average r :  10.3
# save weights:  1700 episodes
#  1800/20000 [.....] - ETA: 9:18:13 Average r :  11.6
# save weights:  1800 episodes
#  1900/20000 [.....] - ETA: 9:14:13 Average r :  14.2
# save weights:  1900 episodes
#  2000/20000 [.....] - ETA: 9:11:25 Average r :  15.5
# save weights:  2000 episodes
#  2100/20000 [.....] - ETA: 9:09:13 Average r :  6.4
# save weights:  2100 episodes
#  2200/20000 [.....] - ETA: 9:06:55 Average r :  9.0
# save weights:  2200 episodes
#  2300/20000 [.....] - ETA: 9:03:32 Average r :  22.0
# save weights:  2300 episodes
#  2400/20000 [.....] - ETA: 9:01:01 Average r :  3.8
# save weights:  2400 episodes
#  2500/20000 [.....] - ETA: 8:57:48 Average r :  18.1
# save weights:  2500 episodes
#  2600/20000 [.....] - ETA: 8:54:07 Average r :  19.4
# save weights:  2600 episodes
#  2700/20000 [.....] - ETA: 8:51:44 Average r :  10.3
# save weights:  2700 episodes
#  2800/20000 [.....] - ETA: 8:48:23 Average r :  19.4
# save weights:  2800 episodes
#  2900/20000 [.....] - ETA: 8:45:18 Average r :  12.9
# save weights:  2900 episodes
#  3000/20000 [.....] - ETA: 8:42:20 Average r :  14.2
# save weights:  3000 episodes
#  3100/20000 [.....] - ETA: 8:39:06 Average r :  14.2
# save weights:  3100 episodes
#  3200/20000 [.....] - ETA: 8:35:49 Average r :  22.0
# save weights:  3200 episodes
#  3300/20000 [.....] - ETA: 8:32:27 Average r :  16.8
# save weights:  3300 episodes
#  3400/20000 [.....] - ETA: 8:29:53 Average r :  10.3
# save weights:  3400 episodes
#  3500/20000 [.....] - ETA: 8:26:38 Average r :  11.6
# save weights:  3500 episodes
#  3600/20000 [.....] - ETA: 8:23:14 Average r :  22.0
# save weights:  3600 episodes
#  3700/20000 [.....] - ETA: 8:20:36 Average r :  10.3
# save weights:  3700 episodes
#  3800/20000 [.....] - ETA: 8:17:55 Average r :  7.7
# save weights:  3800 episodes
#  3900/20000 [.....] - ETA: 8:14:55 Average r :  18.1
# save weights:  3900 episodes
#  4000/20000 [>....] - ETA: 8:12:03 Average r :  7.7
# save weights:  4000 episodes
#  4100/20000 [>....] - ETA: 8:08:55 Average r :  16.8
# save weights:  4100 episodes
#  4200/20000 [>....] - ETA: 8:05:04 Average r :  18.1
# save weights:  4200 episodes
#  4300/20000 [>....] - ETA: 8:01:36 Average r :  18.1
# save weights:  4300 episodes
#  4400/20000 [>....] - ETA: 7:57:55 Average r :  23.3
# save weights:  4400 episodes
#  4500/20000 [>....] - ETA: 7:54:28 Average r :  18.1
# save weights:  4500 episodes
#  4600/20000 [>....] - ETA: 7:51:10 Average r :  10.3
# save weights:  4600 episodes
#  4700/20000 [>....] - ETA: 7:47:35 Average r :  19.4
# save weights:  4700 episodes
#  4800/20000 [>....] - ETA: 7:44:19 Average r :  19.4
# save weights:  4800 episodes
#  4900/20000 [>....] - ETA: 7:41:35 Average r :  9.0
# save weights:  4900 episodes
#  5000/20000 [>....] - ETA: 7:38:07 Average r :  22.0
# save weights:  5000 episodes
#  5100/20000 [>....] - ETA: 7:34:41 Average r :  23.3
# save weights:  5100 episodes
#  5200/20000 [>....] - ETA: 7:31:09 Average r :  16.8
# save weights:  5200 episodes
#  5300/20000 [>....] - ETA: 7:27:50 Average r :  22.0
# save weights:  5300 episodes
#  5400/20000 [>....] - ETA: 7:24:25 Average r :  23.3
# save weights:  5400 episodes
#  5500/20000 [>....] - ETA: 7:21:10 Average r :  14.2
# save weights:  5500 episodes
#  5600/20000 [>....] - ETA: 7:17:43 Average r :  20.7
# save weights:  5600 episodes
#  5700/20000 [>....] - ETA: 7:14:30 Average r :  15.5
# save weights:  5700 episodes
#  5800/20000 [>....] - ETA: 7:11:24 Average r :  14.2
# save weights:  5800 episodes
#  5900/20000 [>....] - ETA: 7:08:38 Average r :  12.9
# save weights:  5900 episodes
#  6000/20000 [>....] - ETA: 7:05:31 Average r :  12.9
# save weights:  6000 episodes
#  6100/20000 [>....] - ETA: 7:02:00 Average r :  22.0
# save weights:  6100 episodes
#  6200/20000 [>....] - ETA: 6:58:55 Average r :  15.5
# save weights:  6200 episodes
#  6300/20000 [>....] - ETA: 6:55:54 Average r :  19.4
# save weights:  6300 episodes
#  6400/20000 [>....] - ETA: 6:53:10 Average r :  12.9
# save weights:  6400 episodes
#  6500/20000 [>....] - ETA: 6:49:40 Average r :  28.5
# save weights:  6500 episodes
#  6600/20000 [>....] - ETA: 6:46:39 Average r :  15.5
# save weights:  6600 episodes
#  6700/20000 [>....] - ETA: 6:43:33 Average r :  14.2
# save weights:  6700 episodes
#  6800/20000 [>....] - ETA: 6:40:40 Average r :  14.2
# save weights:  6800 episodes
#  6900/20000 [>....] - ETA: 6:37:56 Average r :  6.4
# save weights:  6900 episodes
#  7000/20000 [>....] - ETA: 6:34:42 Average r :  19.4
# save weights:  7000 episodes
#  7100/20000 [>....] - ETA: 6:31:18 Average r :  23.3
# save weights:  7100 episodes
#  7200/20000 [>....] - ETA: 6:28:20 Average r :  10.3
# save weights:  7200 episodes
#  7300/20000 [>....] - ETA: 6:25:23 Average r :  6.4
# save weights:  7300 episodes
#  7400/20000 [>....] - ETA: 6:22:13 Average r :  22.0
# save weights:  7400 episodes
#  7500/20000 [>....] - ETA: 6:18:53 Average r :  27.2
# save weights:  7500 episodes
#  7600/20000 [>....] - ETA: 6:15:56 Average r :  10.3
# save weights:  7600 episodes
#  7700/20000 [>....] - ETA: 6:12:56 Average r :  14.2
# save weights:  7700 episodes
#  7800/20000 [>....] - ETA: 6:09:50 Average r :  11.6
# save weights:  7800 episodes
#  7900/20000 [>....] - ETA: 6:06:59 Average r :  18.1
# save weights:  7900 episodes
#  8000/20000 [=>...] - ETA: 6:04:01 Average r :  12.9
# save weights:  8000 episodes
#  8100/20000 [=>...] - ETA: 6:00:54 Average r :  20.7
# save weights:  8100 episodes
#  8200/20000 [=>...] - ETA: 5:57:48 Average r :  25.9
# save weights:  8200 episodes
#  8300/20000 [=>...] - ETA: 5:54:57 Average r :  9.0
# save weights:  8300 episodes
#  8400/20000 [=>...] - ETA: 5:51:55 Average r :  15.5
# save weights:  8400 episodes
#  8500/20000 [=>...] - ETA: 5:48:52 Average r :  14.2
# save weights:  8500 episodes
#  8600/20000 [=>...] - ETA: 5:45:54 Average r :  22.0
# save weights:  8600 episodes
#  8700/20000 [=>...] - ETA: 5:42:49 Average r :  16.8
# save weights:  8700 episodes
#  8800/20000 [=>...] - ETA: 5:39:42 Average r :  23.3
# save weights:  8800 episodes
#  8900/20000 [=>...] - ETA: 5:36:43 Average r :  15.5
# save weights:  8900 episodes
#  9000/20000 [=>...] - ETA: 5:33:37 Average r :  10.3
# save weights:  9000 episodes
#  9100/20000 [=>...] - ETA: 5:30:33 Average r :  19.4
# save weights:  9100 episodes
#  9200/20000 [=>...] - ETA: 5:27:42 Average r :  9.0
# save weights:  9200 episodes
#  9300/20000 [=>...] - ETA: 5:24:26 Average r :  20.7
# save weights:  9300 episodes
#  9400/20000 [=>...] - ETA: 5:21:12 Average r :  27.2
# save weights:  9400 episodes
#  9500/20000 [=>...] - ETA: 5:18:09 Average r :  16.8
# save weights:  9500 episodes
#  9600/20000 [=>...] - ETA: 5:14:56 Average r :  23.3
# save weights:  9600 episodes
#  9700/20000 [=>...] - ETA: 5:11:29 Average r :  40.2
# save weights:  9700 episodes
#  9800/20000 [=>...] - ETA: 5:08:13 Average r :  33.7
# save weights:  9800 episodes
#  9900/20000 [=>...] - ETA: 5:05:03 Average r :  28.5
# save weights:  9900 episodes
# 10000/20000 [=>...] - ETA: 5:01:40 Average r :  46.7
# save weights:  10000 episodes
# 10100/20000 [=>...] - ETA: 4:58:17 Average r :  46.7
# save weights:  10100 episodes
# 10200/20000 [=>...] - ETA: 4:54:49 Average r :  44.1
# save weights:  10200 episodes
# 10300/20000 [=>...] - ETA: 4:51:30 Average r :  32.4
# save weights:  10300 episodes
# 10400/20000 [=>...] - ETA: 4:48:07 Average r :  37.6
# save weights:  10400 episodes
# 10500/20000 [=>...] - ETA: 4:44:43 Average r :  48.0
# save weights:  10500 episodes
# 10600/20000 [=>...] - ETA: 4:41:12 Average r :  50.6
# save weights:  10600 episodes
# 10700/20000 [=>...] - ETA: 4:37:41 Average r :  45.4
# save weights:  10700 episodes
# 10800/20000 [=>...] - ETA: 4:34:17 Average r :  46.7
# save weights:  10800 episodes
# 10900/20000 [=>...] - ETA: 4:30:49 Average r :  42.8
# save weights:  10900 episodes
# 11000/20000 [=>...] - ETA: 4:27:18 Average r :  57.1
# save weights:  11000 episodes
# 11100/20000 [=>...] - ETA: 4:23:43 Average r :  66.2
# save weights:  11100 episodes
# 11200/20000 [=>...] - ETA: 4:20:10 Average r :  57.1
# save weights:  11200 episodes
# 11300/20000 [=>...] - ETA: 4:16:36 Average r :  51.9
# save weights:  11300 episodes
# 11400/20000 [=>...] - ETA: 4:13:11 Average r :  44.1
# save weights:  11400 episodes
# 11500/20000 [=>...] - ETA: 4:09:37 Average r :  59.7
# save weights:  11500 episodes
# 11600/20000 [=>...] - ETA: 4:06:09 Average r :  51.9
# save weights:  11600 episodes
# 11700/20000 [=>...] - ETA: 4:02:37 Average r :  53.2
# save weights:  11700 episodes
# 11800/20000 [=>...] - ETA: 3:59:05 Average r :  54.5
# save weights:  11800 episodes
# 11900/20000 [=>...] - ETA: 3:55:34 Average r :  54.5
# save weights:  11900 episodes
# 12000/20000 [==>..] - ETA: 3:52:05 Average r :  55.8
# save weights:  12000 episodes
# 12100/20000 [==>..] - ETA: 3:48:42 Average r :  54.5
# save weights:  12100 episodes
# 12200/20000 [==>..] - ETA: 3:45:16 Average r :  53.2
# save weights:  12200 episodes
# 12300/20000 [==>..] - ETA: 3:41:49 Average r :  57.1
# save weights:  12300 episodes
# 12400/20000 [==>..] - ETA: 3:38:22 Average r :  58.4
# save weights:  12400 episodes
# 12500/20000 [==>..] - ETA: 3:34:57 Average r :  45.4
# save weights:  12500 episodes
# 12600/20000 [==>..] - ETA: 3:31:39 Average r :  48.0
# save weights:  12600 episodes
# 12700/20000 [==>..] - ETA: 3:28:21 Average r :  46.7
# save weights:  12700 episodes
# 12800/20000 [==>..] - ETA: 3:25:00 Average r :  50.6
# save weights:  12800 episodes
# 12900/20000 [==>..] - ETA: 3:21:43 Average r :  46.7
# save weights:  12900 episodes
# 13000/20000 [==>..] - ETA: 3:18:22 Average r :  50.6
# save weights:  13000 episodes
# 13100/20000 [==>..] - ETA: 3:15:10 Average r :  42.8
# save weights:  13100 episodes
# 13200/20000 [==>..] - ETA: 3:11:56 Average r :  44.1
# save weights:  13200 episodes
# 13300/20000 [==>..] - ETA: 3:08:39 Average r :  51.9
# save weights:  13300 episodes
# 13400/20000 [==>..] - ETA: 3:05:24 Average r :  46.7
# save weights:  13400 episodes
# 13500/20000 [==>..] - ETA: 3:02:11 Average r :  46.7
# save weights:  13500 episodes
# 13600/20000 [==>..] - ETA: 2:59:02 Average r :  42.8
# save weights:  13600 episodes
# 13700/20000 [==>..] - ETA: 2:55:53 Average r :  40.2
# save weights:  13700 episodes
# 13800/20000 [==>..] - ETA: 2:52:45 Average r :  42.8
# save weights:  13800 episodes
# 13900/20000 [==>..] - ETA: 2:49:38 Average r :  40.2
# save weights:  13900 episodes
# 14000/20000 [==>..] - ETA: 2:46:34 Average r :  36.3
# save weights:  14000 episodes
# 14100/20000 [==>..] - ETA: 2:43:26 Average r :  48.0
# save weights:  14100 episodes
# 14200/20000 [==>..] - ETA: 2:40:24 Average r :  36.3
# save weights:  14200 episodes
# 14300/20000 [==>..] - ETA: 2:37:23 Average r :  32.4
# save weights:  14300 episodes
# 14400/20000 [==>..] - ETA: 2:34:21 Average r :  40.2
# save weights:  14400 episodes
# 14500/20000 [==>..] - ETA: 2:31:22 Average r :  32.4
# save weights:  14500 episodes
# 14600/20000 [==>..] - ETA: 2:28:31 Average r :  19.4
# save weights:  14600 episodes
# 14699/20000 [==>..] - ETA: 2:25:37 Average r :  27.2
# save weights:  14700 episodes
# 14800/20000 [==>..] - ETA: 2:22:36 Average r :  35.0
# save weights:  14800 episodes
# 14900/20000 [==>..] - ETA: 2:19:39 Average r :  41.5
# save weights:  14900 episodes
# 15000/20000 [==>..] - ETA: 2:16:38 Average r :  42.8
# save weights:  15000 episodes
# 15100/20000 [==>..] - ETA: 2:13:49 Average r :  20.7
# save weights:  15100 episodes
# 15200/20000 [==>..] - ETA: 2:10:58 Average r :  28.5
# save weights:  15200 episodes
# 15300/20000 [==>..] - ETA: 2:08:03 Average r :  32.4
# save weights:  15300 episodes
# 15400/20000 [==>..] - ETA: 2:05:07 Average r :  37.6
# save weights:  15400 episodes
# 15500/20000 [==>..] - ETA: 2:02:16 Average r :  27.2
# save weights:  15500 episodes
# 15600/20000 [==>..] - ETA: 1:59:28 Average r :  25.9
# save weights:  15600 episodes
# 15700/20000 [==>..] - ETA: 1:56:36 Average r :  28.5
# save weights:  15700 episodes
# 15800/20000 [==>..] - ETA: 1:53:45 Average r :  27.2
# save weights:  15800 episodes
# 15900/20000 [==>..] - ETA: 1:50:57 Average r :  22.0
# save weights:  15900 episodes
# 16000/20000 [===>.] - ETA: 1:48:10 Average r :  19.4
# save weights:  16000 episodes
# 16100/20000 [===>.] - ETA: 1:45:25 Average r :  12.9
# save weights:  16100 episodes
# 16200/20000 [===>.] - ETA: 1:42:37 Average r :  31.1
# save weights:  16200 episodes
# 16300/20000 [===>.] - ETA: 1:39:51 Average r :  15.5
# save weights:  16300 episodes
# 16400/20000 [===>.] - ETA: 1:37:03 Average r :  25.9
# save weights:  16400 episodes
# 16500/20000 [===>.] - ETA: 1:34:18 Average r :  19.4
# save weights:  16500 episodes
# 16600/20000 [===>.] - ETA: 1:31:32 Average r :  24.6
# save weights:  16600 episodes
# 16700/20000 [===>.] - ETA: 1:28:43 Average r :  33.7
# save weights:  16700 episodes
# 16800/20000 [===>.] - ETA: 1:26:00 Average r :  19.4
# save weights:  16800 episodes
# 16899/20000 [===>.] - ETA: 1:23:16 Average r :  18.1
# save weights:  16900 episodes
# 17000/20000 [===>.] - ETA: 1:20:28 Average r :  29.8
# save weights:  17000 episodes
# 17100/20000 [===>.] - ETA: 1:17:41 Average r :  31.1
# save weights:  17100 episodes
# 17200/20000 [===>.] - ETA: 1:14:56 Average r :  28.5
# save weights:  17200 episodes
# 17300/20000 [===>.] - ETA: 1:12:13 Average r :  23.3
# save weights:  17300 episodes
# 17400/20000 [===>.] - ETA: 1:09:28 Average r :  27.2
# save weights:  17400 episodes
# 17500/20000 [===>.] - ETA: 1:06:45 Average r :  22.0
# save weights:  17500 episodes
# 17513/20000 [===>.] - ETA: 1:06:24

# %%
# %%javascript
# Jupyter.notebook.session.delete();
