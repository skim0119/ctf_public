# %% [markdown]
# # Capture the Flag (RL - Policy Gradient)
#
# - Seung Hyun Kim
# - skim449@illinois.edu
#
# ## Notes
# - This notebook includes:
#     - Building the structure of policy driven network.
#     - Training with/without render
#     - Saver that save model and weights to ./model directory
#     - Writer that will record some necessary datas to ./logs
# - This notebook does not include running the CtF game with the RL policy. Using the network will be separately scripted in policy/policy_RL1.py.
#     - cap_test.py is changed appropriately.
#
# ## References :
# - https://github.com/awjuliani/DeepRL-Agents/blob/master/Vanilla-Policy.ipynb (source)
# - https://www.youtube.com/watch?v=PDbXPBwOavc

# %% [markdown]
# !rm -rf logs/B4R4_Rzero_VANILLA/ model/B4R4_Rzero_VANILLA

# %%
TRAIN_NAME='B4R4_Rzero_VANILLA'
LOG_PATH='./logs/'+TRAIN_NAME
MODEL_PATH='./model/' + TRAIN_NAME
GPU_CAPACITY=0.125 # gpu capacity in percentage

# %%
import os

import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.layers as layers
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt
# %matplotlib inline

import time
from datetime import datetime
import gym
import gym_cap
import gym_cap.envs.const as CONST
import numpy as np
import random

# the modules that you can use to generate the policy.
import policy.patrol 
import policy.random
import policy.simple # custon written policy
import policy.policy_RL
import policy.zeros

# Data Processing Module
from DataModule import one_hot_encoder
from Utils import MovingAverage as MA
from Utils import Experience_buffer, discount_rewards

# %% [markdown]
# ## Hyperparameters

# %%
# Training Related
total_episodes = 500000 #Set total number of episodes to train agent on.
max_ep = 150
update_frequency = 50
batch_size = 2000
experience_size=10000

# Saving Related
save_network_frequency = 1000
save_stat_frequency = 100
moving_average_step = 100

# Parameters
LEARNING_RATE = 1e-3
gamma = 0.99
MAP_SIZE = 10
VISION_RANGE = 5
VISION_dX, VISION_dY = 2*VISION_RANGE+1, 2*VISION_RANGE+1

# %% [markdown]
# ## Environment Setting

# %%
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)
    
#Create a directory to save episode playback gifs to
if not os.path.exists(LOG_PATH):
    os.makedirs(LOG_PATH)

# %%
env = gym.make("cap-v0") # initialize the environment
policy_red = policy.zeros.PolicyGen(env.get_map, env.get_team_red)
#plt.imshow(env.render(mode='rgb_array'))
# Environment Related
action_space = 5
n_agent = len(env.get_team_blue)

print('red number : ', len(env.get_team_red))
print('blue number : ', len(env.get_team_blue))
# Out:
# red number :  4
# blue number :  4

# %% [markdown]
# ## Network Setting

# %%
class agent():
    def __init__(self, lr, in_size,action_size):
        #These lines established the feed-forward part of the network. The agent takes a state and produces an action.
        self.state_input = tf.placeholder(shape=in_size,dtype=tf.float32, name='state')
        
        layer = slim.conv2d(self.state_input, 32, [5,5], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv1')
        layer = slim.max_pool2d(layer, [2,2])
        layer = slim.conv2d(layer, 64, [3,3], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv2')
        layer = slim.max_pool2d(layer, [2,2])
        layer = slim.conv2d(layer, 64, [2,2], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv3')
        layer = slim.flatten(layer)
        #flat  = tf.reshape(conv, [-1, VISION_dX*VISION_dY*128])
        #layer = slim.dropout(layer,keep_prob=0.8)
        #layer = slim.fully_connected(layer, 516,
        #                            activation_fn=tf.nn.relu,
        #                            biases_initializer=None,
        #                            scope='hidden_fc1')
        layer = layers.fully_connected(layer, 128, 
                                    activation_fn=tf.nn.relu)
        self.dense = layers.fully_connected(layer, action_size,
                                    activation_fn=None,
                                    scope='output_fc')
        self.output = tf.nn.softmax(self.dense, name='action')
        
        #The next six lines establish the training proceedure. We feed the reward and chosen action into the network
        #to compute the loss, and use it to update the network.
    
        with tf.name_scope('action_placement'):
            self.action_holder = tf.placeholder(shape=[None],dtype=tf.int32)
            self.indexes = tf.range(0, tf.shape(self.output)[0]) * tf.shape(self.output)[1] + self.action_holder

        with tf.name_scope('Loss'):
            self.reward_holder = tf.placeholder(shape=[None],dtype=tf.float32)
            self.responsible_outputs = tf.gather(tf.reshape(self.output, [-1]), self.indexes) # output
            self.loss = -tf.reduce_sum(tf.log(self.responsible_outputs)*self.reward_holder)

        tvars = tf.trainable_variables()
        self.gradient_holders = []
        for idx,var in enumerate(tvars):
            placeholder = tf.placeholder(tf.float32,name=str(idx)+'_holder')
            self.gradient_holders.append(placeholder)

        with tf.name_scope('optimizer'):
            optimizer = tf.train.AdamOptimizer(learning_rate=lr)
            
        '''with tf.name_scope('Loss'):            
        self.loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
                        logits=self.dense, labels=self.action_holder)*self.reward_holder)
        
        with tf.name_scope('optimizer'):
            optimizer = tf.train.AdamOptimizer(learning_rate=lr)
            self.update_batch = optimizer.minimize(self.loss)'''
            
        with tf.name_scope('gradients'):
            self.gradients = tf.gradients(self.loss,tvars)
            self.gradients = [tf.clip_by_norm(grad, 50) for grad in self.gradients]
            #self.gradients = optimizer.compute_gradients(self.loss, tvars)
            

        with tf.name_scope('update'):
            self.update_batch = optimizer.apply_gradients(zip(self.gradient_holders,tvars))
                            
        # Summary
        # Histogram output
        with tf.variable_scope('debug_parameters'):
            tf.summary.histogram('output', self.output)
            tf.summary.histogram('actor', self.dense)     
            tf.summary.histogram('action', self.action_holder)
        
        # Graph summary Loss
        with tf.variable_scope('summary'):
            tf.summary.scalar(name='total_loss', tensor=self.loss)
        
        with tf.variable_scope('weights_bias'):
            # Histogram weights and bias
            for var in slim.get_model_variables():
                tf.summary.histogram(var.op.name, var)
                
        with tf.variable_scope('gradients'):
            # Histogram Gradients
            for var, grad in zip(slim.get_model_variables(), self.gradients):
                tf.summary.histogram(var.op.name+'/grad', grad[0])

# %%
tf.reset_default_graph() # Clear the Tensorflow graph.
myAgent = agent(lr=LEARNING_RATE,in_size=[None,VISION_dX,VISION_dY,6],action_size=5) #Load the agent.
global_step = tf.Variable(0, trainable=False, name='global_step') # global step
increment_global_step_op = tf.assign(global_step, global_step+1)
merged = tf.summary.merge_all()
# Out:
# /home/namsong/github/ctf_public/venv/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# ## Session

# %%
# Launch the session
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=GPU_CAPACITY, allow_growth=True)

sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
#sess = tf.Session()

ma_reward = MA(moving_average_step)
ma_length = MA(moving_average_step)
ma_captured = MA(moving_average_step)

# Setup Save and Restore Network
saver = tf.train.Saver(tf.global_variables())
writer = tf.summary.FileWriter(LOG_PATH, sess.graph)

ckpt = tf.train.get_checkpoint_state(MODEL_PATH)
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("Load Model : ", ckpt.model_checkpoint_path)
else:
    sess.run(tf.global_variables_initializer())
    print("Initialized Variables")
# Out:
# INFO:tensorflow:Restoring parameters from ./model/B4R4_Rzero_VANILLA/ctf_policy.ckpt-157000
# Load Model :  ./model/B4R4_Rzero_VANILLA/ctf_policy.ckpt-157000

# %%
def record(summary_):
    with tf.device('/cpu:0'): 
        summary = tf.Summary()
        summary.value.add(tag='Records/mean_reward', simple_value=ma_reward())
        summary.value.add(tag='Records/mean_length', simple_value=ma_length())
        summary.value.add(tag='Records/mean_succeed', simple_value=ma_captured())
        writer.add_summary(summary, sess.run(global_step))
        
        #summary_str = sess.run(merged,feed_dict={myAgent.state_input:obs})
        writer.add_summary(summary_, sess.run(global_step))
        
        writer.flush()

# %%
gradBuffer = sess.run(tf.trainable_variables())
def clear_buffer():
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0 #np.zeros(grad.shape)

# %%
def policy_rollout(DETERMINISTIC=True):
    # Run single episode, return the results
    s = env.reset(map_size=MAP_SIZE, policy_red=policy_red)
    #obs = one_hot_encoder(s, env.get_team_blue) # partial observation
    obs_next = one_hot_encoder(env._env, env.get_team_blue, VISION_RANGE)
    
    ep_history = []
    indv_history = [[] for _ in range(len(env.get_team_blue))]
    
    was_alive = [ag.isAlive for ag in env.get_team_blue]
    prev_reward=0
    frame=0
    for frame in range(max_ep+1):
        obs = obs_next
        
        with tf.device('/cpu:0'):
            #Probabilistically pick an action given our network outputs.
            act_prob = sess.run(myAgent.output, feed_dict={myAgent.state_input:obs})
        if DETERMINISTIC:
            act = np.argmax(act_prob, axis=1).tolist()
        else:
            act = [np.random.choice(action_space, p=act_prob[x]/sum(act_prob[x])) for x in range(n_agent)] # divide by sum : normalize
            
        s,r1,d,_ = env.step(act) #Get our reward for taking an action given a bandit.

        r = r1-prev_reward

        if frame == max_ep and d == False:
            #r -= frame * (30/1000)
            r = -100
            r1 = -100

        obs_next = one_hot_encoder(env._env, env.get_team_blue, VISION_RANGE) # Full Observation
        
        # Push history for individual that 'was' alive previous frame
        for idx, agent in enumerate(env.get_team_blue):
            if was_alive[idx]:
                indv_history[idx].append([obs[idx],act[idx],r])

        # If reward sequence change, push the history into the episode history.
        '''if prev_reward != r:
            for idx, history in enumerate(indv_history):
                if len(history)==0: continue
                if not was_alive[idx]: continue
                _history = np.array(history)
                _history[:,2] = discount_rewards(_history[:,2])
                ep_history.extend(_history)'''
        
        # State Transition
        prev_reward = r1
        was_alive = [ag.isAlive for ag in env.get_team_blue]
        
        if d:
            break

    for idx, history in enumerate(indv_history):
        if len(history)==0: continue
        _history = np.array(history)
        _history[:,2] = discount_rewards(_history[:,2], gamma)
        ep_history.extend(_history)
            
    if len(ep_history) > 0:        
        ep_history = np.stack(ep_history)
    
    return [frame, ep_history, r1, env.blue_win, obs]

# %% [markdown]
# ## Training

# %%
if __name__=='__main__':
    ep = sess.run(global_step)

    exp_buffer = Experience_buffer(experience_shape=3)
    clear_buffer()
    lost_pass = 1
    try:
        #progbar = tf.keras.utils.Progbar(total_episodes,width=5, stateful_metrics=[datetime.now()], interval=0.5)
        while ep < total_episodes+1:
            # Run episode
            frame, history, reward, did_won, obs = policy_rollout(DETERMINISTIC=False)

            # Add history
            #if did_won or np.random.random_sample() < lost_pass:
            exp_buffer.add(history)

            batch_history = exp_buffer.sample(batch_size) # Sample from experience replay
            if len(batch_history) > 0:
                feed_dict={myAgent.reward_holder:batch_history[:,2],
                       myAgent.action_holder:batch_history[:,1],
                       myAgent.state_input:np.stack(batch_history[:,0])}
                with tf.device('/gpu:0'):
                    loss, grads, summary_ = sess.run([myAgent.loss, myAgent.gradients, merged], feed_dict=feed_dict)
                if ep % save_stat_frequency == 0 and ep != 0:
                    record(summary_)

                for idx,grad in enumerate(grads):
                    gradBuffer[idx] += grad

            if ep % update_frequency == 0 and ep != 0:
                feed_dict= dictionary = dict(zip(myAgent.gradient_holders, gradBuffer))
                with tf.device('/gpu:0'):
                    _ = sess.run(myAgent.update_batch, feed_dict=feed_dict)
                clear_buffer()
                exp_buffer.flush()
                print('train completed: ', ep)
                #progbar.update(ep) # update progress bar
                
            ma_reward.append(reward)
            ma_length.append(frame)
            ma_captured.append(env.blue_win)
            
            # save every 100 ep
            if ep % save_network_frequency == 0 and ep != 0:
                #print(' Average r : ', np.mean(ma_reward[-save_network_frequency:]))
                saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
                #print("save weights: ", sess.run(global_step), 'episodes')

            ep += 1

            sess.run(increment_global_step_op)

    except KeyboardInterrupt:
        print('\n\nManually stopped the training (KeyboardInterrupt)');
        saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
        print("save: ", sess.run(global_step), 'episodes')
# Out:
# train completed:  157000
# train completed:  157050
# train completed:  157100
# train completed:  157150
# train completed:  157200
# train completed:  157250
# train completed:  157300
# train completed:  157350
# train completed:  157400
# train completed:  157450
# train completed:  157500
# train completed:  157550
# train completed:  157600
# train completed:  157650
# train completed:  157700
# train completed:  157750
# train completed:  157800
# train completed:  157850
# train completed:  157900
# train completed:  157950
# train completed:  158000
# train completed:  158050
# train completed:  158100
# train completed:  158150
# train completed:  158200
# train completed:  158250
# train completed:  158300
# train completed:  158350
# train completed:  158400
# train completed:  158450
# train completed:  158500
# train completed:  158550
# train completed:  158600
# train completed:  158650
# train completed:  158700
# train completed:  158750
# train completed:  158800
# train completed:  158850
# train completed:  158900
# train completed:  158950
# train completed:  159000
# train completed:  159050
# train completed:  159100
# train completed:  159150
# train completed:  159200
# train completed:  159250
# train completed:  159300
# train completed:  159350
# train completed:  159400
# train completed:  159450
# train completed:  159500
# train completed:  159550
# train completed:  159600
# train completed:  159650
# train completed:  159700
# train completed:  159750
# train completed:  159800
# train completed:  159850
# train completed:  159900
# train completed:  159950
# train completed:  160000
# train completed:  160050
# train completed:  160100
# train completed:  160150
# train completed:  160200
# train completed:  160250
# train completed:  160300
# train completed:  160350
# train completed:  160400
# train completed:  160450
# train completed:  160500
# train completed:  160550
# train completed:  160600
# train completed:  160650
# train completed:  160700
# train completed:  160750
# train completed:  160800
# train completed:  160850
# train completed:  160900
# train completed:  160950
# train completed:  161000
# train completed:  161050
# train completed:  161100
# train completed:  161150
# train completed:  161200
# train completed:  161250
# train completed:  161300
# train completed:  161350
# train completed:  161400
# train completed:  161450
# train completed:  161500
# train completed:  161550
# train completed:  161600
# train completed:  161650
# train completed:  161700
# train completed:  161750
# train completed:  161800
# train completed:  161850
# train completed:  161900
# train completed:  161950
# train completed:  162000
# train completed:  162050
# train completed:  162100
# train completed:  162150
# train completed:  162200
# train completed:  162250
# train completed:  162300
# train completed:  162350
# train completed:  162400
# train completed:  162450
# train completed:  162500
# train completed:  162550
# train completed:  162600
# train completed:  162650
# train completed:  162700
# train completed:  162750
# train completed:  162800
# train completed:  162850
# train completed:  162900
# train completed:  162950
# train completed:  163000
# train completed:  163050
# train completed:  163100
# train completed:  163150
# train completed:  163200
# train completed:  163250
# train completed:  163300
# train completed:  163350
# train completed:  163400
# train completed:  163450
# train completed:  163500
# train completed:  163550
# train completed:  163600
# train completed:  163650
# train completed:  163700
# train completed:  163750
# train completed:  163800
# train completed:  163850
# train completed:  163900
# train completed:  163950
# train completed:  164000
# train completed:  164050
# train completed:  164100
# train completed:  164150
# train completed:  164200
# train completed:  164250
# train completed:  164300
# train completed:  164350
# train completed:  164400
# train completed:  164450
# train completed:  164500
# train completed:  164550
# train completed:  164600
# train completed:  164650
# train completed:  164700
# train completed:  164750
# train completed:  164800
# train completed:  164850
# train completed:  164900
# train completed:  164950
# train completed:  165000
# train completed:  165050
# train completed:  165100
# train completed:  165150
# train completed:  165200
# train completed:  165250
# train completed:  165300
# train completed:  165350
# train completed:  165400
# train completed:  165450
# train completed:  165500
# train completed:  165550
# train completed:  165600
# train completed:  165650
# train completed:  165700
# train completed:  165750
# train completed:  165800
# train completed:  165850
# train completed:  165900
# train completed:  165950
# train completed:  166000
# train completed:  166050
# train completed:  166100
# train completed:  166150
# train completed:  166200
# train completed:  166250
# train completed:  166300
# train completed:  166350
# train completed:  166400
# train completed:  166450
# train completed:  166500
# train completed:  166550
# train completed:  166600
# train completed:  166650
# train completed:  166700
# train completed:  166750
# train completed:  166800
# train completed:  166850
# train completed:  166900
# train completed:  166950
# train completed:  167000
# train completed:  167050
# train completed:  167100
# train completed:  167150
# train completed:  167200
# train completed:  167250
# train completed:  167300
# train completed:  167350
# train completed:  167400
# train completed:  167450
# train completed:  167500
# train completed:  167550
# train completed:  167600
# train completed:  167650
# train completed:  167700
# train completed:  167750
# train completed:  167800
# train completed:  167850
# train completed:  167900
# train completed:  167950
# train completed:  168000
# train completed:  168050
# train completed:  168100
# train completed:  168150
# train completed:  168200
# train completed:  168250
# train completed:  168300
# train completed:  168350
# train completed:  168400
# train completed:  168450
# train completed:  168500
# train completed:  168550
# train completed:  168600
# train completed:  168650
# train completed:  168700
# train completed:  168750
# train completed:  168800
# train completed:  168850
# train completed:  168900
# train completed:  168950
# train completed:  169000
# train completed:  169050
# train completed:  169100
# train completed:  169150
# train completed:  169200
# train completed:  169250
# train completed:  169300
# train completed:  169350
# train completed:  169400
# train completed:  169450
# train completed:  169500
# train completed:  169550
# train completed:  169600
# train completed:  169650
# train completed:  169700
# train completed:  169750
# train completed:  169800
# train completed:  169850
# train completed:  169900
# train completed:  169950
# train completed:  170000
# train completed:  170050
# train completed:  170100
# train completed:  170150
# train completed:  170200
# train completed:  170250
# train completed:  170300
# train completed:  170350
# train completed:  170400
# train completed:  170450
# train completed:  170500
# train completed:  170550
# train completed:  170600
# train completed:  170650
# train completed:  170700
# train completed:  170750
# train completed:  170800
# train completed:  170850
# train completed:  170900
# train completed:  170950
# train completed:  171000
# train completed:  171050
# train completed:  171100
# train completed:  171150
# train completed:  171200
# train completed:  171250
# train completed:  171300
# train completed:  171350
# train completed:  171400
# train completed:  171450
# train completed:  171500
# train completed:  171550
# train completed:  171600
# train completed:  171650
# train completed:  171700
# train completed:  171750
# train completed:  171800
# train completed:  171850
# train completed:  171900
# train completed:  171950
# train completed:  172000
# train completed:  172050
# train completed:  172100
# train completed:  172150
# train completed:  172200
# train completed:  172250
# train completed:  172300
# train completed:  172350
# train completed:  172400
# train completed:  172450
# train completed:  172500
# train completed:  172550
# train completed:  172600
# train completed:  172650
# train completed:  172700
# train completed:  172750
# train completed:  172800
# train completed:  172850
# train completed:  172900
# train completed:  172950
# train completed:  173000
# train completed:  173050
# train completed:  173100
# train completed:  173150
# train completed:  173200
# train completed:  173250
# train completed:  173300
# train completed:  173350
# train completed:  173400
# train completed:  173450
# train completed:  173500
# train completed:  173550
# train completed:  173600
# train completed:  173650
# train completed:  173700
# train completed:  173750
# train completed:  173800
# train completed:  173850
# train completed:  173900
# train completed:  173950
# train completed:  174000
# train completed:  174050
# train completed:  174100
# train completed:  174150
# train completed:  174200
# train completed:  174250
# train completed:  174300
# train completed:  174350
# train completed:  174400
# train completed:  174450
# train completed:  174500
# train completed:  174550
# train completed:  174600
# train completed:  174650
# train completed:  174700
# train completed:  174750
# train completed:  174800
# train completed:  174850
# train completed:  174900
# train completed:  174950
# train completed:  175000
# train completed:  175050
# train completed:  175100
# train completed:  175150
# train completed:  175200
# train completed:  175250
# train completed:  175300
# train completed:  175350
# train completed:  175400
# train completed:  175450
# train completed:  175500
# train completed:  175550
# train completed:  175600
# train completed:  175650
# train completed:  175700
# train completed:  175750
# train completed:  175800
# train completed:  175850
# train completed:  175900
# train completed:  175950
# train completed:  176000
# train completed:  176050
# train completed:  176100
# train completed:  176150
# train completed:  176200
# train completed:  176250
# train completed:  176300
# train completed:  176350
# train completed:  176400
# train completed:  176450
# train completed:  176500
# train completed:  176550
# train completed:  176600
# train completed:  176650
# train completed:  176700
# train completed:  176750
# train completed:  176800
# train completed:  176850
# train completed:  176900
# train completed:  176950
# train completed:  177000
# train completed:  177050
# train completed:  177100
# train completed:  177150
# train completed:  177200
# train completed:  177250
# train completed:  177300
# train completed:  177350
# train completed:  177400
# train completed:  177450
# train completed:  177500
# train completed:  177550
# train completed:  177600
# train completed:  177650
# train completed:  177700
# train completed:  177750
# train completed:  177800
# train completed:  177850
# train completed:  177900
# train completed:  177950
# train completed:  178000
# train completed:  178050
# train completed:  178100
# train completed:  178150
# train completed:  178200
# train completed:  178250
# train completed:  178300
# train completed:  178350
# train completed:  178400
# train completed:  178450
# train completed:  178500
# train completed:  178550
# train completed:  178600
# train completed:  178650
# train completed:  178700
# train completed:  178750
# train completed:  178800
# train completed:  178850
# train completed:  178900
# train completed:  178950
# train completed:  179000
# train completed:  179050
# train completed:  179100
# train completed:  179150
# train completed:  179200
# train completed:  179250
# train completed:  179300
# train completed:  179350
# train completed:  179400
# train completed:  179450
# train completed:  179500
# train completed:  179550
# train completed:  179600
# train completed:  179650
# train completed:  179700
# train completed:  179750
# train completed:  179800
# train completed:  179850
# train completed:  179900
# train completed:  179950
# train completed:  180000
# train completed:  180050
# train completed:  180100
# train completed:  180150
# train completed:  180200
# train completed:  180250
# train completed:  180300
# train completed:  180350
# train completed:  180400
# train completed:  180450
# train completed:  180500
# train completed:  180550
# train completed:  180600
# train completed:  180650
# train completed:  180700
# train completed:  180750
# train completed:  180800
# train completed:  180850
# train completed:  180900
# train completed:  180950
# train completed:  181000
# train completed:  181050
# train completed:  181100
# train completed:  181150
# train completed:  181200
# train completed:  181250
# train completed:  181300
# train completed:  181350
# train completed:  181400
# train completed:  181450
# train completed:  181500
# train completed:  181550
# train completed:  181600
# train completed:  181650
# train completed:  181700
# train completed:  181750
# train completed:  181800
# train completed:  181850
# train completed:  181900
# train completed:  181950
# train completed:  182000
# train completed:  182050
# train completed:  182100
# train completed:  182150
# train completed:  182200
# train completed:  182250
# train completed:  182300
# train completed:  182350
# train completed:  182400
# train completed:  182450
# train completed:  182500
# train completed:  182550
# train completed:  182600
# train completed:  182650
# train completed:  182700
# train completed:  182750
# train completed:  182800
# train completed:  182850
# train completed:  182900
# train completed:  182950
# train completed:  183000
# train completed:  183050
# train completed:  183100
# train completed:  183150
# train completed:  183200
# train completed:  183250
# train completed:  183300
# train completed:  183350
# train completed:  183400
# train completed:  183450
# train completed:  183500
# train completed:  183550
# train completed:  183600
# train completed:  183650
# train completed:  183700
# train completed:  183750
# train completed:  183800
# train completed:  183850
# train completed:  183900
# train completed:  183950
# train completed:  184000
# train completed:  184050
# train completed:  184100
# train completed:  184150
# train completed:  184200
# train completed:  184250
# train completed:  184300
# train completed:  184350
# train completed:  184400
# train completed:  184450
# train completed:  184500
# train completed:  184550
# train completed:  184600
# train completed:  184650
# train completed:  184700
# train completed:  184750
# train completed:  184800
# train completed:  184850
# train completed:  184900
# train completed:  184950
# train completed:  185000
# train completed:  185050
# train completed:  185100
# train completed:  185150
# train completed:  185200
# train completed:  185250
# train completed:  185300
# train completed:  185350
# train completed:  185400
# train completed:  185450
# train completed:  185500
# train completed:  185550
# train completed:  185600
# train completed:  185650
# train completed:  185700
# train completed:  185750
# train completed:  185800
# train completed:  185850
# train completed:  185900
# train completed:  185950
# train completed:  186000
# train completed:  186050
# train completed:  186100
# train completed:  186150
# train completed:  186200
# train completed:  186250
# train completed:  186300
# train completed:  186350
# train completed:  186400
# train completed:  186450
# train completed:  186500
# train completed:  186550
# train completed:  186600
# train completed:  186650
# train completed:  186700
# train completed:  186750
# train completed:  186800
# train completed:  186850
# train completed:  186900
# train completed:  186950
# train completed:  187000
# train completed:  187050
# train completed:  187100
# train completed:  187150
# train completed:  187200
# train completed:  187250
# train completed:  187300
# train completed:  187350
# train completed:  187400
# train completed:  187450
# train completed:  187500
# train completed:  187550
# train completed:  187600
# train completed:  187650
# train completed:  187700
# train completed:  187750
# train completed:  187800
# train completed:  187850
# train completed:  187900
# train completed:  187950
# train completed:  188000
# train completed:  188050
# train completed:  188100
# train completed:  188150
# train completed:  188200
# train completed:  188250
# train completed:  188300
# train completed:  188350
# train completed:  188400
# train completed:  188450
# train completed:  188500
# train completed:  188550
# train completed:  188600
# train completed:  188650
# train completed:  188700
# train completed:  188750
# train completed:  188800
# train completed:  188850
# train completed:  188900
# train completed:  188950
# train completed:  189000
# train completed:  189050
# train completed:  189100
# train completed:  189150
# train completed:  189200
# train completed:  189250
# train completed:  189300
# train completed:  189350
# train completed:  189400
# train completed:  189450
# train completed:  189500
# train completed:  189550
# train completed:  189600
# train completed:  189650
# train completed:  189700
# train completed:  189750
# train completed:  189800
# train completed:  189850
# train completed:  189900
# train completed:  189950
# train completed:  190000
# train completed:  190050
# train completed:  190100
# train completed:  190150
# train completed:  190200
# train completed:  190250
# train completed:  190300
# train completed:  190350
# train completed:  190400
# train completed:  190450
# train completed:  190500
# train completed:  190550
# train completed:  190600
# train completed:  190650
# train completed:  190700
# train completed:  190750
# train completed:  190800
# train completed:  190850
# train completed:  190900
# train completed:  190950
# train completed:  191000
# train completed:  191050
# train completed:  191100
# train completed:  191150
# train completed:  191200
# train completed:  191250
# train completed:  191300
# train completed:  191350
# train completed:  191400
# train completed:  191450
# train completed:  191500
# train completed:  191550
# train completed:  191600
# train completed:  191650
# train completed:  191700
# train completed:  191750
# train completed:  191800
# train completed:  191850
# train completed:  191900
# train completed:  191950
# train completed:  192000
# train completed:  192050
# train completed:  192100
# train completed:  192150
# train completed:  192200
# train completed:  192250
# train completed:  192300
# train completed:  192350
# train completed:  192400
# train completed:  192450
# train completed:  192500
# train completed:  192550
# train completed:  192600
# train completed:  192650
# train completed:  192700
# train completed:  192750
# train completed:  192800
# train completed:  192850
# train completed:  192900
# train completed:  192950
# train completed:  193000
# train completed:  193050
# train completed:  193100
# train completed:  193150
# train completed:  193200
# train completed:  193250
# train completed:  193300
# train completed:  193350
# train completed:  193400
# train completed:  193450
# train completed:  193500
# train completed:  193550
# train completed:  193600
# train completed:  193650
# train completed:  193700
# train completed:  193750
# train completed:  193800
# train completed:  193850
# train completed:  193900
# train completed:  193950
# train completed:  194000
# train completed:  194050
# train completed:  194100
# train completed:  194150
# train completed:  194200
# train completed:  194250
# train completed:  194300
# train completed:  194350
# train completed:  194400
# train completed:  194450
# train completed:  194500
# train completed:  194550
# train completed:  194600
# train completed:  194650
# train completed:  194700
# train completed:  194750
# train completed:  194800
# train completed:  194850
# train completed:  194900
# train completed:  194950
# train completed:  195000
# train completed:  195050
# train completed:  195100
# train completed:  195150
# train completed:  195200
# train completed:  195250
# train completed:  195300
# train completed:  195350
# train completed:  195400
# train completed:  195450
# train completed:  195500
# train completed:  195550
# train completed:  195600
# train completed:  195650
# train completed:  195700
# train completed:  195750
# train completed:  195800
# train completed:  195850
# train completed:  195900
# train completed:  195950
# train completed:  196000
# train completed:  196050
# train completed:  196100
# train completed:  196150
# train completed:  196200
# train completed:  196250
# train completed:  196300
# train completed:  196350
# train completed:  196400
# train completed:  196450
# train completed:  196500
# train completed:  196550
# train completed:  196600
# train completed:  196650
# train completed:  196700
# train completed:  196750
# train completed:  196800
# train completed:  196850
# train completed:  196900
# train completed:  196950
# train completed:  197000
# train completed:  197050
# train completed:  197100
# train completed:  197150
# train completed:  197200
# train completed:  197250
# train completed:  197300
# train completed:  197350
# train completed:  197400
# train completed:  197450
# train completed:  197500
# train completed:  197550
# train completed:  197600
# train completed:  197650
# train completed:  197700
# train completed:  197750
# train completed:  197800
# train completed:  197850
# train completed:  197900
# train completed:  197950
# train completed:  198000
# train completed:  198050
# train completed:  198100
# train completed:  198150
# train completed:  198200
# train completed:  198250
# train completed:  198300
# train completed:  198350
# train completed:  198400
# train completed:  198450
# train completed:  198500
# train completed:  198550
# train completed:  198600
# train completed:  198650
# train completed:  198700
# train completed:  198750
# train completed:  198800
# train completed:  198850
# train completed:  198900
# train completed:  198950
# train completed:  199000
# train completed:  199050
# train completed:  199100
# train completed:  199150
# train completed:  199200
# train completed:  199250
# train completed:  199300
# train completed:  199350
# train completed:  199400
# train completed:  199450
# train completed:  199500
# train completed:  199550
# train completed:  199600
# train completed:  199650
# train completed:  199700
# train completed:  199750
# train completed:  199800
# train completed:  199850
# train completed:  199900
# train completed:  199950
# train completed:  200000
# train completed:  200050
# train completed:  200100
# train completed:  200150
# train completed:  200200
# train completed:  200250
# train completed:  200300
# train completed:  200350
# train completed:  200400
# train completed:  200450
# train completed:  200500
# train completed:  200550
# train completed:  200600
# train completed:  200650
# train completed:  200700
# train completed:  200750
# train completed:  200800
# train completed:  200850
# train completed:  200900
# train completed:  200950
# train completed:  201000
# train completed:  201050
# train completed:  201100
# train completed:  201150
# train completed:  201200
# train completed:  201250
# train completed:  201300
# train completed:  201350
# train completed:  201400
# train completed:  201450
# train completed:  201500
# train completed:  201550
# train completed:  201600
# train completed:  201650
# train completed:  201700
# train completed:  201750
# train completed:  201800
# train completed:  201850
# train completed:  201900
# train completed:  201950
# train completed:  202000
# train completed:  202050
# train completed:  202100
# train completed:  202150
# train completed:  202200
# train completed:  202250
# train completed:  202300
# train completed:  202350
# train completed:  202400
# train completed:  202450
# train completed:  202500
# train completed:  202550
# train completed:  202600
# train completed:  202650
# train completed:  202700
# train completed:  202750
# train completed:  202800
# train completed:  202850
# train completed:  202900
# train completed:  202950
# train completed:  203000
# train completed:  203050
# train completed:  203100
# train completed:  203150
# train completed:  203200
# train completed:  203250
# train completed:  203300
# train completed:  203350
# train completed:  203400
# train completed:  203450
# train completed:  203500
# train completed:  203550
# train completed:  203600
# train completed:  203650
# train completed:  203700
# train completed:  203750
# train completed:  203800
# train completed:  203850
# train completed:  203900
# train completed:  203950
# train completed:  204000
# train completed:  204050
# train completed:  204100
# train completed:  204150
# train completed:  204200
# train completed:  204250
# train completed:  204300
# train completed:  204350
# train completed:  204400
# train completed:  204450
# train completed:  204500
# train completed:  204550
# train completed:  204600
# train completed:  204650
# train completed:  204700
# train completed:  204750
# train completed:  204800
# train completed:  204850
# train completed:  204900
# train completed:  204950
# train completed:  205000
# train completed:  205050
# train completed:  205100
# train completed:  205150
# train completed:  205200
# train completed:  205250
# train completed:  205300
# train completed:  205350
# train completed:  205400
# train completed:  205450
# train completed:  205500
# train completed:  205550
# train completed:  205600
# train completed:  205650
# train completed:  205700
# train completed:  205750
# train completed:  205800
# train completed:  205850
# train completed:  205900
# train completed:  205950
# train completed:  206000
# train completed:  206050
# train completed:  206100
# train completed:  206150
# train completed:  206200
# train completed:  206250
# train completed:  206300
# train completed:  206350
# train completed:  206400
# train completed:  206450
# train completed:  206500
# train completed:  206550
# train completed:  206600
# train completed:  206650
# train completed:  206700
# train completed:  206750
# train completed:  206800
# train completed:  206850
# train completed:  206900
# train completed:  206950
# train completed:  207000
# train completed:  207050
# train completed:  207100
# train completed:  207150
# train completed:  207200
# train completed:  207250
# train completed:  207300
# train completed:  207350
# train completed:  207400
# train completed:  207450
# train completed:  207500
# train completed:  207550
# train completed:  207600
# train completed:  207650
# train completed:  207700
# train completed:  207750
# train completed:  207800
# train completed:  207850
# train completed:  207900
# train completed:  207950
# train completed:  208000
# train completed:  208050
# train completed:  208100
# train completed:  208150
# train completed:  208200
# train completed:  208250
# train completed:  208300
# train completed:  208350
# train completed:  208400
# train completed:  208450
# train completed:  208500
# train completed:  208550
# train completed:  208600
# train completed:  208650
# train completed:  208700
# train completed:  208750
# train completed:  208800
# train completed:  208850
# train completed:  208900
# train completed:  208950
# train completed:  209000
# train completed:  209050
# train completed:  209100
# train completed:  209150
# train completed:  209200
# train completed:  209250
# train completed:  209300
# train completed:  209350
# train completed:  209400
# train completed:  209450
# train completed:  209500
# train completed:  209550
# train completed:  209600
# train completed:  209650
# train completed:  209700
# train completed:  209750
# train completed:  209800
# train completed:  209850
# train completed:  209900
# train completed:  209950
# train completed:  210000
# train completed:  210050
# train completed:  210100
# train completed:  210150
# train completed:  210200
# train completed:  210250
# train completed:  210300
# train completed:  210350
# train completed:  210400
# train completed:  210450
# train completed:  210500
# train completed:  210550
# train completed:  210600
# train completed:  210650
# train completed:  210700
# train completed:  210750
# train completed:  210800
# train completed:  210850
# train completed:  210900
# train completed:  210950
# train completed:  211000
# train completed:  211050
# train completed:  211100
# train completed:  211150
# train completed:  211200
# train completed:  211250
# train completed:  211300
# train completed:  211350
# train completed:  211400
# train completed:  211450
# train completed:  211500
# train completed:  211550
# train completed:  211600
# train completed:  211650
# train completed:  211700
# train completed:  211750
# train completed:  211800
# train completed:  211850
# train completed:  211900
# train completed:  211950
# train completed:  212000
# train completed:  212050
# train completed:  212100
# train completed:  212150
# train completed:  212200
# train completed:  212250
# train completed:  212300
# train completed:  212350
# train completed:  212400
# train completed:  212450
# train completed:  212500
# train completed:  212550
# train completed:  212600
# train completed:  212650
# train completed:  212700
# train completed:  212750
# train completed:  212800
# train completed:  212850
# train completed:  212900
# train completed:  212950
# train completed:  213000
# train completed:  213050
# train completed:  213100
# train completed:  213150
# train completed:  213200
# train completed:  213250
# train completed:  213300
# train completed:  213350
# train completed:  213400
# train completed:  213450
# train completed:  213500
# train completed:  213550
# train completed:  213600
# train completed:  213650
# train completed:  213700
# train completed:  213750
# train completed:  213800
# train completed:  213850
# train completed:  213900
# train completed:  213950
# train completed:  214000
# train completed:  214050
# train completed:  214100
# train completed:  214150
# train completed:  214200
# train completed:  214250
# train completed:  214300
# train completed:  214350
# train completed:  214400
# train completed:  214450
# train completed:  214500
# train completed:  214550
# train completed:  214600
# train completed:  214650
# train completed:  214700
# train completed:  214750
# train completed:  214800
# train completed:  214850
# train completed:  214900
# train completed:  214950
# train completed:  215000
# train completed:  215050
# train completed:  215100
# train completed:  215150
# train completed:  215200
# train completed:  215250
# train completed:  215300
# train completed:  215350
# train completed:  215400
# train completed:  215450
# train completed:  215500
# train completed:  215550
# train completed:  215600
# train completed:  215650
# train completed:  215700
# train completed:  215750
# train completed:  215800
# train completed:  215850
# train completed:  215900
# train completed:  215950
# train completed:  216000
# train completed:  216050
# train completed:  216100
# train completed:  216150
# train completed:  216200
# train completed:  216250
# train completed:  216300
# train completed:  216350
# train completed:  216400
# train completed:  216450
# train completed:  216500
# train completed:  216550
# train completed:  216600
# train completed:  216650
# train completed:  216700
# train completed:  216750
# train completed:  216800
# train completed:  216850
# train completed:  216900
# train completed:  216950
# train completed:  217000
# train completed:  217050
# train completed:  217100
# train completed:  217150
# train completed:  217200
# train completed:  217250
# train completed:  217300
# train completed:  217350
# train completed:  217400
# train completed:  217450
# train completed:  217500
# train completed:  217550
# train completed:  217600
# train completed:  217650
# train completed:  217700
# train completed:  217750
# train completed:  217800
# train completed:  217850
# train completed:  217900
# train completed:  217950
# train completed:  218000
# train completed:  218050
# train completed:  218100
# train completed:  218150
# train completed:  218200
# train completed:  218250
# train completed:  218300
# train completed:  218350
# train completed:  218400
# train completed:  218450
# train completed:  218500
# train completed:  218550
# train completed:  218600
# train completed:  218650
# train completed:  218700
# train completed:  218750
# train completed:  218800
# train completed:  218850
# train completed:  218900
# train completed:  218950
# train completed:  219000
# train completed:  219050
# train completed:  219100
# train completed:  219150
# train completed:  219200
# train completed:  219250
# train completed:  219300
# train completed:  219350
# train completed:  219400
# train completed:  219450
# train completed:  219500
# train completed:  219550
# train completed:  219600
# train completed:  219650
# train completed:  219700
# train completed:  219750
# train completed:  219800
# train completed:  219850
# train completed:  219900
# train completed:  219950
# train completed:  220000
# train completed:  220050
# train completed:  220100
# train completed:  220150
# train completed:  220200
# train completed:  220250
# train completed:  220300
# train completed:  220350
# train completed:  220400
# train completed:  220450
# train completed:  220500
# train completed:  220550
# train completed:  220600
# train completed:  220650
# train completed:  220700
# train completed:  220750
# train completed:  220800
# train completed:  220850
# train completed:  220900
# train completed:  220950
# train completed:  221000
# train completed:  221050
# train completed:  221100
# train completed:  221150
# train completed:  221200
# train completed:  221250
# train completed:  221300
# train completed:  221350
# train completed:  221400
# train completed:  221450
# train completed:  221500
# train completed:  221550
# train completed:  221600
# train completed:  221650
# train completed:  221700
# train completed:  221750
# train completed:  221800
# train completed:  221850
# train completed:  221900
# train completed:  221950
# train completed:  222000
# train completed:  222050
# train completed:  222100
# train completed:  222150
# train completed:  222200
# train completed:  222250
# train completed:  222300
# train completed:  222350
# train completed:  222400
# train completed:  222450
# train completed:  222500
# train completed:  222550
# train completed:  222600
# train completed:  222650
# train completed:  222700
# train completed:  222750
# train completed:  222800
# train completed:  222850
# train completed:  222900
# train completed:  222950
# train completed:  223000
# train completed:  223050
# train completed:  223100
# train completed:  223150
# train completed:  223200
# train completed:  223250
# train completed:  223300
# train completed:  223350
# train completed:  223400
# train completed:  223450
# train completed:  223500
# train completed:  223550
# train completed:  223600
# train completed:  223650
# train completed:  223700
# train completed:  223750
# train completed:  223800
# train completed:  223850
# train completed:  223900
# train completed:  223950
# train completed:  224000
# train completed:  224050
# train completed:  224100
# train completed:  224150
# train completed:  224200
# train completed:  224250
# train completed:  224300
# train completed:  224350
# train completed:  224400
# train completed:  224450
# train completed:  224500
# train completed:  224550
# train completed:  224600
# train completed:  224650
# train completed:  224700
# train completed:  224750
# train completed:  224800
# train completed:  224850
# train completed:  224900
# train completed:  224950
# train completed:  225000
# train completed:  225050
# train completed:  225100
# train completed:  225150
# train completed:  225200
# train completed:  225250
# train completed:  225300
# train completed:  225350
# train completed:  225400
# train completed:  225450
# train completed:  225500
# train completed:  225550
# train completed:  225600
# train completed:  225650
# train completed:  225700
# train completed:  225750
# train completed:  225800
# train completed:  225850
# train completed:  225900
# train completed:  225950
# train completed:  226000
# train completed:  226050
# train completed:  226100
# train completed:  226150
# train completed:  226200
# train completed:  226250
# train completed:  226300
# train completed:  226350
# train completed:  226400
# train completed:  226450
# train completed:  226500
# train completed:  226550
# train completed:  226600
# train completed:  226650
# train completed:  226700
# train completed:  226750
# train completed:  226800
# train completed:  226850
# train completed:  226900
# train completed:  226950
# train completed:  227000
# train completed:  227050
# train completed:  227100
# train completed:  227150
# train completed:  227200
# train completed:  227250
# train completed:  227300
# train completed:  227350
# train completed:  227400
# train completed:  227450
# train completed:  227500
# train completed:  227550
# train completed:  227600
# train completed:  227650
# train completed:  227700
# train completed:  227750
# train completed:  227800
# train completed:  227850
# train completed:  227900
# train completed:  227950
# train completed:  228000
# train completed:  228050
# train completed:  228100
# train completed:  228150
# train completed:  228200
# train completed:  228250
# train completed:  228300
# train completed:  228350
# train completed:  228400
# train completed:  228450
# train completed:  228500
# train completed:  228550
# train completed:  228600
# train completed:  228650
# train completed:  228700
# train completed:  228750
# train completed:  228800
# train completed:  228850
# train completed:  228900
# train completed:  228950
# train completed:  229000
# train completed:  229050
# train completed:  229100
# train completed:  229150
# train completed:  229200
# train completed:  229250
# train completed:  229300
# train completed:  229350
# train completed:  229400
# train completed:  229450
# train completed:  229500
# train completed:  229550
# train completed:  229600
# train completed:  229650
# train completed:  229700
# train completed:  229750
# train completed:  229800
# train completed:  229850
# train completed:  229900
# train completed:  229950
# train completed:  230000
# train completed:  230050
# train completed:  230100
# train completed:  230150
# train completed:  230200
# train completed:  230250
# train completed:  230300
# train completed:  230350
# train completed:  230400
# train completed:  230450
# train completed:  230500
# train completed:  230550
# train completed:  230600
# train completed:  230650
# train completed:  230700
# train completed:  230750
# train completed:  230800
# train completed:  230850
# train completed:  230900
# train completed:  230950
# train completed:  231000
# train completed:  231050
# train completed:  231100
# train completed:  231150
# train completed:  231200
# train completed:  231250
# train completed:  231300
# train completed:  231350
# train completed:  231400
# train completed:  231450
# train completed:  231500
# train completed:  231550
# train completed:  231600
# train completed:  231650
# train completed:  231700
# train completed:  231750
# train completed:  231800
# train completed:  231850
# train completed:  231900
# train completed:  231950
# train completed:  232000
# train completed:  232050
# train completed:  232100
# train completed:  232150
# train completed:  232200
# train completed:  232250
# train completed:  232300
# train completed:  232350
# train completed:  232400
# train completed:  232450
# train completed:  232500
# train completed:  232550
# train completed:  232600
# train completed:  232650
# train completed:  232700
# train completed:  232750
# train completed:  232800
# train completed:  232850
# train completed:  232900
# train completed:  232950
# train completed:  233000
# train completed:  233050
# train completed:  233100
# train completed:  233150
# train completed:  233200
# train completed:  233250
# train completed:  233300
# train completed:  233350
# train completed:  233400
# train completed:  233450
# train completed:  233500
# train completed:  233550
# train completed:  233600
# train completed:  233650
# train completed:  233700
# train completed:  233750
# train completed:  233800
# train completed:  233850
# train completed:  233900
# train completed:  233950
# train completed:  234000
# train completed:  234050
# train completed:  234100
# train completed:  234150
# train completed:  234200
# train completed:  234250
# train completed:  234300
# train completed:  234350
# train completed:  234400
# train completed:  234450
# train completed:  234500
# train completed:  234550
# train completed:  234600
# train completed:  234650
# train completed:  234700
# train completed:  234750
# train completed:  234800
# train completed:  234850
# train completed:  234900
# train completed:  234950
# train completed:  235000
# train completed:  235050
# train completed:  235100
# train completed:  235150
# train completed:  235200
# train completed:  235250
# train completed:  235300
# train completed:  235350
# train completed:  235400
# train completed:  235450
# train completed:  235500
# train completed:  235550
# train completed:  235600
# train completed:  235650
# train completed:  235700
# train completed:  235750
# train completed:  235800
# train completed:  235850
# train completed:  235900
# train completed:  235950
# train completed:  236000
# train completed:  236050
# train completed:  236100
# train completed:  236150
# train completed:  236200
# train completed:  236250
# train completed:  236300
# train completed:  236350
# train completed:  236400
# train completed:  236450
# train completed:  236500
# train completed:  236550
# train completed:  236600
# train completed:  236650
# train completed:  236700
# train completed:  236750
# train completed:  236800
# train completed:  236850
# train completed:  236900
# train completed:  236950
# train completed:  237000
# train completed:  237050
# train completed:  237100
# train completed:  237150
# train completed:  237200
# train completed:  237250
# train completed:  237300
# train completed:  237350
# train completed:  237400
# train completed:  237450
# train completed:  237500
# train completed:  237550
# train completed:  237600
# train completed:  237650
# train completed:  237700
# train completed:  237750
# train completed:  237800
# train completed:  237850
# train completed:  237900
# train completed:  237950
# train completed:  238000
# train completed:  238050
# train completed:  238100
# train completed:  238150
# train completed:  238200
# train completed:  238250
# train completed:  238300
# train completed:  238350
# train completed:  238400
# train completed:  238450
# train completed:  238500
# train completed:  238550
# train completed:  238600
# train completed:  238650
# train completed:  238700
# train completed:  238750
# train completed:  238800
# train completed:  238850
# train completed:  238900
# train completed:  238950
# train completed:  239000
# train completed:  239050
# train completed:  239100
# train completed:  239150
# train completed:  239200
# train completed:  239250
# train completed:  239300
# train completed:  239350
# train completed:  239400
# train completed:  239450
# train completed:  239500
# train completed:  239550
# train completed:  239600
# train completed:  239650
# train completed:  239700
# train completed:  239750
# train completed:  239800
# train completed:  239850
# train completed:  239900
# train completed:  239950
# train completed:  240000
# train completed:  240050
# train completed:  240100
# train completed:  240150
# train completed:  240200
# train completed:  240250
# train completed:  240300
# train completed:  240350
# train completed:  240400
# train completed:  240450
# train completed:  240500
# train completed:  240550
# train completed:  240600
# train completed:  240650
# train completed:  240700
# train completed:  240750
# train completed:  240800
# train completed:  240850
# train completed:  240900
# train completed:  240950
# train completed:  241000
# train completed:  241050
# train completed:  241100
# train completed:  241150
# train completed:  241200
# train completed:  241250
# train completed:  241300
# train completed:  241350
# train completed:  241400
# train completed:  241450
# train completed:  241500
# train completed:  241550
# train completed:  241600
# train completed:  241650
# train completed:  241700
# train completed:  241750
# train completed:  241800
# train completed:  241850
# train completed:  241900
# train completed:  241950
# train completed:  242000
# train completed:  242050
# train completed:  242100
# train completed:  242150
# train completed:  242200
# train completed:  242250
# train completed:  242300
# train completed:  242350
# train completed:  242400
# train completed:  242450
# train completed:  242500
# train completed:  242550
# train completed:  242600
# train completed:  242650
# train completed:  242700
# train completed:  242750
# train completed:  242800
# train completed:  242850
# train completed:  242900
# train completed:  242950
# train completed:  243000
# train completed:  243050
# train completed:  243100
# train completed:  243150
# train completed:  243200
# train completed:  243250
# train completed:  243300
# train completed:  243350
# train completed:  243400
# train completed:  243450
# train completed:  243500
# train completed:  243550
# train completed:  243600
# train completed:  243650
# train completed:  243700
# train completed:  243750
# train completed:  243800
# train completed:  243850
# train completed:  243900
# train completed:  243950
# train completed:  244000
# train completed:  244050
# train completed:  244100
# train completed:  244150
# train completed:  244200
# train completed:  244250
# train completed:  244300
# train completed:  244350
# train completed:  244400
# train completed:  244450
# train completed:  244500
# train completed:  244550
# train completed:  244600
# train completed:  244650
# train completed:  244700
# train completed:  244750
# train completed:  244800
# train completed:  244850
# train completed:  244900
# train completed:  244950
# train completed:  245000
# train completed:  245050
# train completed:  245100
# train completed:  245150
# train completed:  245200
# train completed:  245250
# train completed:  245300
# train completed:  245350
# train completed:  245400
# train completed:  245450
# train completed:  245500
# train completed:  245550
# train completed:  245600
# train completed:  245650
# train completed:  245700
# train completed:  245750
# train completed:  245800
# train completed:  245850
# train completed:  245900
# train completed:  245950
# train completed:  246000
# train completed:  246050
# train completed:  246100
# train completed:  246150
# train completed:  246200
# train completed:  246250
# train completed:  246300
# train completed:  246350
# train completed:  246400
# train completed:  246450
# train completed:  246500
# train completed:  246550
# train completed:  246600
# train completed:  246650
# train completed:  246700
# train completed:  246750
# train completed:  246800
# train completed:  246850
# train completed:  246900
# train completed:  246950
# train completed:  247000
# train completed:  247050
# train completed:  247100
# train completed:  247150
# train completed:  247200
# train completed:  247250
# train completed:  247300
# train completed:  247350
# train completed:  247400
# train completed:  247450
# train completed:  247500
# train completed:  247550
# train completed:  247600
# train completed:  247650
# train completed:  247700
# train completed:  247750
# train completed:  247800
# train completed:  247850
# train completed:  247900
# train completed:  247950
# train completed:  248000
# train completed:  248050
# train completed:  248100
# train completed:  248150
# train completed:  248200
# train completed:  248250
# train completed:  248300
# train completed:  248350
# train completed:  248400
# train completed:  248450
# train completed:  248500
# train completed:  248550
# train completed:  248600
# train completed:  248650
# train completed:  248700
# train completed:  248750
# train completed:  248800
# train completed:  248850
# train completed:  248900
# train completed:  248950
# train completed:  249000
# train completed:  249050
# train completed:  249100
# train completed:  249150
# train completed:  249200
# train completed:  249250
# train completed:  249300
# train completed:  249350
# train completed:  249400
# train completed:  249450
# train completed:  249500
# train completed:  249550
# train completed:  249600
# train completed:  249650
# train completed:  249700
# train completed:  249750
# train completed:  249800
# train completed:  249850
# train completed:  249900
# train completed:  249950
# train completed:  250000
# train completed:  250050
# train completed:  250100
# train completed:  250150
# train completed:  250200
# train completed:  250250
# train completed:  250300
# train completed:  250350
# train completed:  250400
# train completed:  250450
# train completed:  250500
# train completed:  250550
# train completed:  250600
# train completed:  250650
# train completed:  250700
# train completed:  250750
# train completed:  250800
# train completed:  250850
# train completed:  250900
# train completed:  250950
# train completed:  251000
# train completed:  251050
# train completed:  251100
# train completed:  251150
# train completed:  251200
# train completed:  251250
# train completed:  251300
# train completed:  251350
# train completed:  251400
# train completed:  251450
# train completed:  251500
# train completed:  251550
# train completed:  251600
# train completed:  251650
# train completed:  251700
# train completed:  251750
# train completed:  251800
# train completed:  251850
# train completed:  251900
# train completed:  251950
# train completed:  252000
# train completed:  252050
# train completed:  252100
# train completed:  252150
# train completed:  252200
# train completed:  252250
# train completed:  252300
# train completed:  252350
# train completed:  252400
# train completed:  252450
# train completed:  252500
# train completed:  252550
# train completed:  252600
# train completed:  252650
# train completed:  252700
# train completed:  252750
# train completed:  252800
# train completed:  252850
# train completed:  252900
# train completed:  252950
# ...
# train completed:  310050
# train completed:  310100
# train completed:  310150
# train completed:  310200
# train completed:  310250
# train completed:  310300
# train completed:  310350
# train completed:  310400
# train completed:  310450
# train completed:  310500
# train completed:  310550
# train completed:  310600
# train completed:  310650
# train completed:  310700
# train completed:  310750
# train completed:  310800
# train completed:  310850
# train completed:  310900
# train completed:  310950
# train completed:  311000
# train completed:  311050
# train completed:  311100
# train completed:  311150
# train completed:  311200
# train completed:  311250
# train completed:  311300
# train completed:  311350
# train completed:  311400
# train completed:  311450
# train completed:  311500
# train completed:  311550
# train completed:  311600
# train completed:  311650
# train completed:  311700
# train completed:  311750
# train completed:  311800
# train completed:  311850
# train completed:  311900
# train completed:  311950
# train completed:  312000
# train completed:  312050
# train completed:  312100
# train completed:  312150
# train completed:  312200
# train completed:  312250
# train completed:  312300
# train completed:  312350
# train completed:  312400
# train completed:  312450
# train completed:  312500
# train completed:  312550
# train completed:  312600
# train completed:  312650
# train completed:  312700
# train completed:  312750
# train completed:  312800
# train completed:  312850
# train completed:  312900
# train completed:  312950
# train completed:  313000
# train completed:  313050
# train completed:  313100
# train completed:  313150
# train completed:  313200
# train completed:  313250
# train completed:  313300
# train completed:  313350
# train completed:  313400
# train completed:  313450
# train completed:  313500
# train completed:  313550
# train completed:  313600
# train completed:  313650
# train completed:  313700
# train completed:  313750
# train completed:  313800
# train completed:  313850
# train completed:  313900
# train completed:  313950
# train completed:  314000
# train completed:  314050
# train completed:  314100
# train completed:  314150
# train completed:  314200
# train completed:  314250
# train completed:  314300
# train completed:  314350
# train completed:  314400
# train completed:  314450
# train completed:  314500
# train completed:  314550
# train completed:  314600
# train completed:  314650
# train completed:  314700
# train completed:  314750
# train completed:  314800
# train completed:  314850
# train completed:  314900
# train completed:  314950
# train completed:  315000
# train completed:  315050
# train completed:  315100
# train completed:  315150
# train completed:  315200
# train completed:  315250
# train completed:  315300
# train completed:  315350
# train completed:  315400
# train completed:  315450
# train completed:  315500
# train completed:  315550
# train completed:  315600
# train completed:  315650
# train completed:  315700
# train completed:  315750
# train completed:  315800
# train completed:  315850
# train completed:  315900
# train completed:  315950
# train completed:  316000
# train completed:  316050
# train completed:  316100
# train completed:  316150
# train completed:  316200
# train completed:  316250
# train completed:  316300
# train completed:  316350
# train completed:  316400
# train completed:  316450
# train completed:  316500
# train completed:  316550
# train completed:  316600
# train completed:  316650
# train completed:  316700
# train completed:  316750
# train completed:  316800
# train completed:  316850
# train completed:  316900
# train completed:  316950
# train completed:  317000
# train completed:  317050
# train completed:  317100
# train completed:  317150
# train completed:  317200
# train completed:  317250
# train completed:  317300
# train completed:  317350
# train completed:  317400
# train completed:  317450
# train completed:  317500
# train completed:  317550
# train completed:  317600
# train completed:  317650
# train completed:  317700
# train completed:  317750
# train completed:  317800
# train completed:  317850
# train completed:  317900
# train completed:  317950
# train completed:  318000
# train completed:  318050
# train completed:  318100
# train completed:  318150
# train completed:  318200
# train completed:  318250
# train completed:  318300
# train completed:  318350
# train completed:  318400
# train completed:  318450
# train completed:  318500
# train completed:  318550
# train completed:  318600
# train completed:  318650
# train completed:  318700
# train completed:  318750
# train completed:  318800
# train completed:  318850
# train completed:  318900
# train completed:  318950
# train completed:  319000
# train completed:  319050
# train completed:  319100
# train completed:  319150
# train completed:  319200
# train completed:  319250
# train completed:  319300
# train completed:  319350
# train completed:  319400
# train completed:  319450
# train completed:  319500
# train completed:  319550
# train completed:  319600
# train completed:  319650
# train completed:  319700
# train completed:  319750
# train completed:  319800
# train completed:  319850
# train completed:  319900
# train completed:  319950
# train completed:  320000
# train completed:  320050
# train completed:  320100
# train completed:  320150
# train completed:  320200
# train completed:  320250
# train completed:  320300
# train completed:  320350
# train completed:  320400
# train completed:  320450
# train completed:  320500
# train completed:  320550
# train completed:  320600
# train completed:  320650
# train completed:  320700
# train completed:  320750
# train completed:  320800
# train completed:  320850
# train completed:  320900
# train completed:  320950
# train completed:  321000
# train completed:  321050
# train completed:  321100
# train completed:  321150
# train completed:  321200
# train completed:  321250
# train completed:  321300
# train completed:  321350
# train completed:  321400
# train completed:  321450
# train completed:  321500
# train completed:  321550
# train completed:  321600
# train completed:  321650
# train completed:  321700
# train completed:  321750
# train completed:  321800
# train completed:  321850
# train completed:  321900
# train completed:  321950
# train completed:  322000
# train completed:  322050
# train completed:  322100
# train completed:  322150
# train completed:  322200
# train completed:  322250
# train completed:  322300
# train completed:  322350
# train completed:  322400
# train completed:  322450
# train completed:  322500
# train completed:  322550
# train completed:  322600
# train completed:  322650
# train completed:  322700
# train completed:  322750
# train completed:  322800
# train completed:  322850
# train completed:  322900
# train completed:  322950
# train completed:  323000
# train completed:  323050
# train completed:  323100
# train completed:  323150
# train completed:  323200
# train completed:  323250
# train completed:  323300
# train completed:  323350
# train completed:  323400
# train completed:  323450
# train completed:  323500
# train completed:  323550
# train completed:  323600
# train completed:  323650
# train completed:  323700
# train completed:  323750
# train completed:  323800
# train completed:  323850
# train completed:  323900
# train completed:  323950
# train completed:  324000
# train completed:  324050
# train completed:  324100
# train completed:  324150
# train completed:  324200
# train completed:  324250
# train completed:  324300
# train completed:  324350
# train completed:  324400
# train completed:  324450
# train completed:  324500
# train completed:  324550
# train completed:  324600
# train completed:  324650
# train completed:  324700
# train completed:  324750
# train completed:  324800
# train completed:  324850
# train completed:  324900
# train completed:  324950
# train completed:  325000
# train completed:  325050
# train completed:  325100
# train completed:  325150
# train completed:  325200
# train completed:  325250
# train completed:  325300
# train completed:  325350
# train completed:  325400
# train completed:  325450
# train completed:  325500
# train completed:  325550
# train completed:  325600
# train completed:  325650
# train completed:  325700
# train completed:  325750
# train completed:  325800
# train completed:  325850
# train completed:  325900
# train completed:  325950
# train completed:  326000
# train completed:  326050
# train completed:  326100
# train completed:  326150
# train completed:  326200
# train completed:  326250
# train completed:  326300
# train completed:  326350
# train completed:  326400
# train completed:  326450
# train completed:  326500
# train completed:  326550
# train completed:  326600
# train completed:  326650
# train completed:  326700
# train completed:  326750
# train completed:  326800
# train completed:  326850
# train completed:  326900
# train completed:  326950
# train completed:  327000
# train completed:  327050
# train completed:  327100
# train completed:  327150
# train completed:  327200
# train completed:  327250
# train completed:  327300
# train completed:  327350
# train completed:  327400
# train completed:  327450
# train completed:  327500
# train completed:  327550
# train completed:  327600
# train completed:  327650
# train completed:  327700
# train completed:  327750
# train completed:  327800
# train completed:  327850
# train completed:  327900
# train completed:  327950
# train completed:  328000
# train completed:  328050
# train completed:  328100
# train completed:  328150
# train completed:  328200
# train completed:  328250
# train completed:  328300
# train completed:  328350
# train completed:  328400
# train completed:  328450
# train completed:  328500
# train completed:  328550
# train completed:  328600
# train completed:  328650
# train completed:  328700
# train completed:  328750
# train completed:  328800
# train completed:  328850
# train completed:  328900
# train completed:  328950
# train completed:  329000
# train completed:  329050
# train completed:  329100
# train completed:  329150
# train completed:  329200
# train completed:  329250
# train completed:  329300
# train completed:  329350
# train completed:  329400
# train completed:  329450
# train completed:  329500
# train completed:  329550
# train completed:  329600
# train completed:  329650
# train completed:  329700
# train completed:  329750
# train completed:  329800
# train completed:  329850
# train completed:  329900
# train completed:  329950
# train completed:  330000
# train completed:  330050
# train completed:  330100
# train completed:  330150
# train completed:  330200
# train completed:  330250
# train completed:  330300
# train completed:  330350
# train completed:  330400
# train completed:  330450
# train completed:  330500
# train completed:  330550
# train completed:  330600
# train completed:  330650
# train completed:  330700
# train completed:  330750
# train completed:  330800
# train completed:  330850
# train completed:  330900
# train completed:  330950
# train completed:  331000
# train completed:  331050
# train completed:  331100
# train completed:  331150
# train completed:  331200
# train completed:  331250
# train completed:  331300
# train completed:  331350
# train completed:  331400
# train completed:  331450
# train completed:  331500
# train completed:  331550
# train completed:  331600
# train completed:  331650
# train completed:  331700
# train completed:  331750
# train completed:  331800
# train completed:  331850
# train completed:  331900
# train completed:  331950
# train completed:  332000
# train completed:  332050
# train completed:  332100
# train completed:  332150
# train completed:  332200
# train completed:  332250
# train completed:  332300
# train completed:  332350
# train completed:  332400
# train completed:  332450
# train completed:  332500
# train completed:  332550
# train completed:  332600
# train completed:  332650
# train completed:  332700
# train completed:  332750
# train completed:  332800
# train completed:  332850
# train completed:  332900
# train completed:  332950
# train completed:  333000
# train completed:  333050
# train completed:  333100
# train completed:  333150
# train completed:  333200
# train completed:  333250
# train completed:  333300
# train completed:  333350
# train completed:  333400
# train completed:  333450
# train completed:  333500
# train completed:  333550
# train completed:  333600
# train completed:  333650
# train completed:  333700
# train completed:  333750
# train completed:  333800
# train completed:  333850
# train completed:  333900
# train completed:  333950
# train completed:  334000
# train completed:  334050
# train completed:  334100
# train completed:  334150
# train completed:  334200
# train completed:  334250
# train completed:  334300
# train completed:  334350
# train completed:  334400
# train completed:  334450
# train completed:  334500
# train completed:  334550
# train completed:  334600
# train completed:  334650
# train completed:  334700
# train completed:  334750
# train completed:  334800
# train completed:  334850
# train completed:  334900
# train completed:  334950
# train completed:  335000
# train completed:  335050
# train completed:  335100
# train completed:  335150
# train completed:  335200
# train completed:  335250
# train completed:  335300
# train completed:  335350
# train completed:  335400
# train completed:  335450
# train completed:  335500
# train completed:  335550
# train completed:  335600
# train completed:  335650
# train completed:  335700
# train completed:  335750
# train completed:  335800
# train completed:  335850
# train completed:  335900
# train completed:  335950
# train completed:  336000
# train completed:  336050
# train completed:  336100
# train completed:  336150
# train completed:  336200
# train completed:  336250
# train completed:  336300
# train completed:  336350
# train completed:  336400
# train completed:  336450
# train completed:  336500
# train completed:  336550
# train completed:  336600
# train completed:  336650
# train completed:  336700
# train completed:  336750
# train completed:  336800
# train completed:  336850
# train completed:  336900
# train completed:  336950
# train completed:  337000
# train completed:  337050
# train completed:  337100
# train completed:  337150
# train completed:  337200
# train completed:  337250
# train completed:  337300
# train completed:  337350
# train completed:  337400
# train completed:  337450
# train completed:  337500
# train completed:  337550
# train completed:  337600
# train completed:  337650
# train completed:  337700
# train completed:  337750
# train completed:  337800
# train completed:  337850
# train completed:  337900
# train completed:  337950
# train completed:  338000
# train completed:  338050
# train completed:  338100
# train completed:  338150
# train completed:  338200
# train completed:  338250
# train completed:  338300
# train completed:  338350
# train completed:  338400
# train completed:  338450
# train completed:  338500
# train completed:  338550
# train completed:  338600
# train completed:  338650
# train completed:  338700
# train completed:  338750
# train completed:  338800
# train completed:  338850
# train completed:  338900
# train completed:  338950
# train completed:  339000
# train completed:  339050
# train completed:  339100
# train completed:  339150
# train completed:  339200
# train completed:  339250
# train completed:  339300
# train completed:  339350
# train completed:  339400
# train completed:  339450
# train completed:  339500
# train completed:  339550
# train completed:  339600
# train completed:  339650
# train completed:  339700
# train completed:  339750
# train completed:  339800
# train completed:  339850
# train completed:  339900
# train completed:  339950
# train completed:  340000
# train completed:  340050
# train completed:  340100
# train completed:  340150
# train completed:  340200
# train completed:  340250
# train completed:  340300
# train completed:  340350
# train completed:  340400
# train completed:  340450
# train completed:  340500
# train completed:  340550
# train completed:  340600
# train completed:  340650
# train completed:  340700
# train completed:  340750
# train completed:  340800
# train completed:  340850
# train completed:  340900
# train completed:  340950
# train completed:  341000
# train completed:  341050
# train completed:  341100
# train completed:  341150
# train completed:  341200
# train completed:  341250
# train completed:  341300
# train completed:  341350
# train completed:  341400
# train completed:  341450
# train completed:  341500
# train completed:  341550
# train completed:  341600
# train completed:  341650
# train completed:  341700
# train completed:  341750
# train completed:  341800
# train completed:  341850
# train completed:  341900
# train completed:  341950
# train completed:  342000
