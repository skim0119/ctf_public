# %% [markdown]
# # Capture the Flag (RL - Policy Gradient)
#
# - Seung Hyun Kim
# - skim449@illinois.edu
#
# ## Notes
# - This notebook includes:
#     - Building the structure of policy driven network.
#     - Training with/without render
#     - Saver that save model and weights to ./model directory
#     - Writer that will record some necessary datas to ./logs
# - This notebook does not include running the CtF game with the RL policy. Using the network will be separately scripted in policy/policy_RL1.py.
#     - cap_test.py is changed appropriately.
#
# ## References :
# - https://github.com/awjuliani/DeepRL-Agents/blob/master/Vanilla-Policy.ipynb (source)
# - https://www.youtube.com/watch?v=PDbXPBwOavc

# %%
TRAIN_NAME='NO_RED_04_Minimizer'
LOG_PATH='./logs/'+TRAIN_NAME
MODEL_PATH='./model/' + TRAIN_NAME
GPU_CAPACITY=0.125 # gpu capacity in percentage

# %%
import os

import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.layers as layers
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt
# %matplotlib inline

import time
import gym
import gym_cap
import gym_cap.envs.const as CONST
import numpy as np
import random

# the modules that you can use to generate the policy.
import policy.patrol 
import policy.random
import policy.simple # custon written policy
import policy.policy_RL
import policy.zeros

# Data Processing Module
from DataModule import one_hot_encoder, VISION_dX, VISION_dY
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Hyperparameters

# %%
# Training Related
total_episodes = 20000 #Set total number of episodes to train agent on.
max_ep = 300
update_frequency = 50
batch_size = 2000
experience_size=50000

# Saving Related
save_network_frequency = 100
save_stat_frequency = 50
moving_average_step = 50

# %% [markdown]
# ## Environment Setting

# %%
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)
    
#Create a directory to save episode playback gifs to
if not os.path.exists(LOG_PATH):
    os.makedirs(LOG_PATH)

# %%
env = gym.make("cap-v0") # initialize the environment
policy_red = policy.random.PolicyGen(env.get_map, env.get_team_red)

# Environment Related
action_space = 5
n_agent = len(env.get_team_blue)

print('red number : ', len(env.get_team_red))
print('blue number : ', len(env.get_team_blue))
# Out:
# red number :  0
# blue number :  4

# %% [markdown]
# ## Discount Reward

# %%
gamma = 0.98

def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0.0
    for t in reversed(range(r.size)):
        running_add = (running_add * gamma + r[t])
        discounted_r[t] = running_add
    #discounted_r = (discounted_r - np.mean(discounted_r)) / (np.std(discounted_r)+1e-8) # normalize
    return discounted_r

# %% [markdown]
# ## Network Setting

# %%
class agent():
    def __init__(self, lr, in_size,action_size):
        #These lines established the feed-forward part of the network. The agent takes a state and produces an action.
        self.state_input = tf.placeholder(shape=in_size,dtype=tf.float32, name='state')
        
        layer = slim.conv2d(self.state_input, 16, [5,5], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv1')
        layer = slim.conv2d(layer, 16, [3,3], activation_fn=tf.nn.relu,
                            weights_initializer=layers.xavier_initializer_conv2d(),
                            biases_initializer=tf.zeros_initializer(),
                            padding='SAME',
                            scope='conv2')
        layer = slim.flatten(layer)
        #flat  = tf.reshape(conv, [-1, VISION_dX*VISION_dY*128])
        #layer = slim.dropout(layer,keep_prob=0.8)
        #layer = slim.fully_connected(layer, 516,
        #                            activation_fn=tf.nn.relu,
        #                            biases_initializer=None,
        #                            scope='hidden_fc1')
        layer = slim.dropout(layer,keep_prob=0.8)
        layer = slim.fully_connected(layer, 1024, 
                                    weights_initializer=layers.xavier_initializer(),
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=tf.zeros_initializer())
        layer = slim.dropout(layer,keep_prob=0.8)
        self.dense = slim.fully_connected(layer, action_size,
                                    weights_initializer=layers.xavier_initializer(),
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=tf.zeros_initializer(),
                                    scope='output_fc')
        self.output = tf.nn.softmax(self.dense, name='action')
        
        tf.summary.histogram('output', self.output)
        
        with tf.name_scope('weights'):
            for var in slim.get_model_variables():
                tf.summary.histogram(var.op.name, var)

        #The next six lines establish the training proceedure. We feed the reward and chosen action into the network
        #to compute the loss, and use it to update the network.
    
        with tf.name_scope('action_placement'):
            self.action_holder = tf.placeholder(shape=[None],dtype=tf.int32)
            self.indexes = tf.range(0, tf.shape(self.output)[0]) * tf.shape(self.output)[1] + self.action_holder

        with tf.name_scope('loss'):
            self.reward_holder = tf.placeholder(shape=[None],dtype=tf.float32)
            self.responsible_outputs = tf.gather(tf.reshape(self.output, [-1]), self.indexes) # output
            self.loss = -tf.reduce_mean(tf.log(self.responsible_outputs)*self.reward_holder)
        
        with tf.name_scope('optimizer'):
            optimizer = tf.train.AdamOptimizer(learning_rate=lr)
            self.update_batch = optimizer.minimize(self.loss)

# %%
tf.reset_default_graph() # Clear the Tensorflow graph.
myAgent = agent(lr=1e-5,in_size=[None,VISION_dX,VISION_dY,6],action_size=5) #Load the agent.
global_step = tf.Variable(0, trainable=False, name='global_step') # global step
increment_global_step_op = tf.assign(global_step, global_step+1)
merged = tf.summary.merge_all()
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# ## Session

# %%
# Launch the session
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=GPU_CAPACITY, allow_growth=True)

sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
#sess = tf.Session()

total_reward = []
total_length = []
total_captured = []
total_loss=[]

# Setup Save and Restore Network
saver = tf.train.Saver(tf.global_variables())
writer = tf.summary.FileWriter(LOG_PATH, sess.graph)

ckpt = tf.train.get_checkpoint_state(MODEL_PATH)
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("Load Model : ", ckpt.model_checkpoint_path)
else:
    sess.run(tf.global_variables_initializer())
    print("Initialized Variables")
# Out:
# Initialized Variables

# %%
def record(obs):
    with tf.device('/cpu:0'): 
        summary = tf.Summary()
        summary.value.add(tag='Records/mean_reward', simple_value=np.mean(total_reward[-moving_average_step:]))
        summary.value.add(tag='Records/mean_length', simple_value=np.mean(total_length[-moving_average_step:]))
        summary.value.add(tag='Records/mean_succeed', simple_value=np.mean(total_captured[-moving_average_step:]))
        summary.value.add(tag='Loss', simple_value=np.mean(total_loss[-moving_average_step:]))
        writer.add_summary(summary, sess.run(global_step))
        
        summary_str = sess.run(merged,feed_dict={myAgent.state_input:obs})
        writer.add_summary(summary_str, sess.run(global_step))
        
        writer.flush()

# %%
class Experience_buffer():
    def __init__(self, buffer_size = experience_size):
        self.buffer = []
        self.buffer_size = buffer_size
    
    def add(self,experience):
        if len(self.buffer) + len(experience) >= self.buffer_size:
            self.buffer[0:(len(experience)+len(self.buffer))-self.buffer_size] = []
        self.buffer.extend(experience)
    
    def flush(self):
        self.buffer = []
        self.buffer_size = 0
    
    def sample(self, size=2000):
        if size > len(self.buffer):
            return np.array(self.buffer)
        else:
            return np.reshape(np.array(random.sample(self.buffer,size)),[size,3])

# %%
def policy_rollout(env):
    # Run single episode, return the results (number of frame, history, total reward, game_won, last obs)
    s = env.reset(map_size=20, policy_red=policy_red)
    ep_history = []
    indv_history = [[] for _ in range(len(env.get_team_blue))]
    
    was_alive = [ag.isAlive for ag in env.get_team_blue]
    prev_reward=0
    for frame in range(max_ep+1):
        #obs = one_hot_encoder(s, env.get_team_blue).tolist() # partial observation
        obs = one_hot_encoder(env._env, env.get_team_blue) # Full observation
        
        with tf.device('/cpu:0'):        
            #Probabilistically pick an action given our network outputs.
            act_prob = sess.run(myAgent.output, feed_dict={myAgent.state_input:obs})
            act = [np.random.choice(action_space, p=act_prob[x]/sum(act_prob[x])) for x in range(n_agent)] # divide by sum : normalize
            
        s,r,d,_ = env.step(act) #Get our reward for taking an action given a bandit.
        
        # If frame is at max and the game is still not done, negative reward
        if frame == max_ep and d == False:
            #r -= frame * (30/150)
            r -= 30
            
        # Push history for individual that 'was' alive previous frame
        for idx, agent in enumerate(env.get_team_blue):
            if was_alive[idx]: indv_history[idx].append([obs[idx],act[idx],r])

        # If reward sequence change, push the history into the episode history.
        if prev_reward != r:
            for idx, history in enumerate(indv_history):
                if len(history)==0: continue
                if not was_alive[idx]: continue
                _history = np.array(history)
                _history[:,2] = discount_rewards(_history[:,2])
                ep_history.extend(_history)
        
        # State Transition
        frame += 1
        prev_reward = r
        was_alive = [ag.isAlive for ag in env.get_team_blue]
        
        if d == True:
            break
    if len(ep_history) > 0:        
        ep_history = np.stack(ep_history)
    
    return [frame, ep_history, r, env.game_won, obs]

# %% [markdown]
# ## Training

# %%
if __name__=='__main__':
    ep = 0

    exp_buffer = Experience_buffer()
    try:
        progbar = tf.keras.utils.Progbar(total_episodes,width=5)
        while ep < total_episodes+1:
            progbar.update(ep) # update progress bar

            # Run episode
            frame, history, reward, did_won, obs = policy_rollout(env)

            # Add history
            exp_buffer.add(history)

            if ep % update_frequency == 0 and ep != 0:
                with tf.device('/gpu:0'): 
                    batch_history = exp_buffer.sample(batch_size) # Sample from experience replay
                    feed_dict={myAgent.reward_holder:batch_history[:,2],
                               myAgent.action_holder:batch_history[:,1],
                               myAgent.state_input:np.stack(batch_history[:,0])}
                    loss, _ = sess.run([myAgent.loss, myAgent.update_batch], feed_dict=feed_dict)
                    total_loss.append(loss)
                    exp_buffer.flush()

            total_reward.append(reward)
            total_length.append(frame)
            total_captured.append(env.game_won)
            if ep % save_stat_frequency == 0 and ep != 0:
                record(obs)

            # save every 100 ep
            if ep % save_network_frequency == 0 and ep != 0:
                print(' Average r : ', np.mean(total_reward[-save_network_frequency:]))
                saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
                print("save weights: ", sess.run(global_step), 'episodes')

            ep += 1
            sess.run(increment_global_step_op)

    except KeyboardInterrupt:
        print('\n\nManually stopped the training (KeyboardInterrupt)');
        plt.plot(total_reward)
        plt.figure()
        plt.plot(total_length)
        plt.figure()
        plt.plot(total_captured)
        saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
        record(obs)
        print("save: ", sess.run(global_step), 'episodes')
# Out:
#   100/20000 [.....] - ETA: 11:00:51 Average r :  14.2
# save weights:  100 episodes
#   200/20000 [.....] - ETA: 10:39:24 Average r :  23.3
# save weights:  200 episodes
#   300/20000 [.....] - ETA: 10:32:54 Average r :  28.5
# save weights:  300 episodes
#   400/20000 [.....] - ETA: 10:33:50 Average r :  15.5
# save weights:  400 episodes
#   500/20000 [.....] - ETA: 10:30:18 Average r :  24.6
# save weights:  500 episodes
#   600/20000 [.....] - ETA: 10:27:05 Average r :  18.1
# save weights:  600 episodes
#   700/20000 [.....] - ETA: 10:25:29 Average r :  25.9
# save weights:  700 episodes
#   800/20000 [.....] - ETA: 10:21:03 Average r :  24.6
# save weights:  800 episodes
#   900/20000 [.....] - ETA: 10:14:08 Average r :  28.5
# save weights:  900 episodes
#  1000/20000 [.....] - ETA: 10:07:21 Average r :  33.7
# save weights:  1000 episodes
#  1100/20000 [.....] - ETA: 10:04:38 Average r :  20.7
# save weights:  1100 episodes
#  1200/20000 [.....] - ETA: 10:00:20 Average r :  37.6
# save weights:  1200 episodes
#  1300/20000 [.....] - ETA: 9:56:41 Average r :  23.3
# save weights:  1300 episodes
#  1400/20000 [.....] - ETA: 9:50:36 Average r :  36.3
# save weights:  1400 episodes
#  1500/20000 [.....] - ETA: 9:47:28 Average r :  32.4
# save weights:  1500 episodes
#  1600/20000 [.....] - ETA: 9:45:47 Average r :  18.1
# save weights:  1600 episodes
#  1700/20000 [.....] - ETA: 9:41:19 Average r :  29.8
# save weights:  1700 episodes
#  1800/20000 [.....] - ETA: 9:37:07 Average r :  25.9
# save weights:  1800 episodes
#  1900/20000 [.....] - ETA: 9:34:14 Average r :  24.6
# save weights:  1900 episodes
#  2000/20000 [.....] - ETA: 9:29:57 Average r :  25.9
# save weights:  2000 episodes
#  2100/20000 [.....] - ETA: 9:28:31 Average r :  22.0
# save weights:  2100 episodes
#  2200/20000 [.....] - ETA: 9:23:41 Average r :  27.2
# save weights:  2200 episodes
#  2300/20000 [.....] - ETA: 9:19:23 Average r :  35.0
# save weights:  2300 episodes
#  2400/20000 [.....] - ETA: 9:14:14 Average r :  46.7
# save weights:  2400 episodes
#  2500/20000 [.....] - ETA: 9:09:12 Average r :  40.2
# save weights:  2500 episodes
#  2600/20000 [.....] - ETA: 9:06:03 Average r :  32.4
# save weights:  2600 episodes
#  2700/20000 [.....] - ETA: 9:02:50 Average r :  37.6
# save weights:  2700 episodes
#  2800/20000 [.....] - ETA: 8:58:53 Average r :  28.5
# save weights:  2800 episodes
#  2900/20000 [.....] - ETA: 8:54:20 Average r :  40.2
# save weights:  2900 episodes
#  3000/20000 [.....] - ETA: 8:49:12 Average r :  45.4
# save weights:  3000 episodes
#  3100/20000 [.....] - ETA: 8:45:01 Average r :  45.4
# save weights:  3100 episodes
#  3200/20000 [.....] - ETA: 8:41:03 Average r :  44.1
# save weights:  3200 episodes
#  3300/20000 [.....] - ETA: 8:36:44 Average r :  44.1
# save weights:  3300 episodes
#  3400/20000 [.....] - ETA: 8:32:41 Average r :  44.1
# save weights:  3400 episodes
#  3500/20000 [.....] - ETA: 8:28:28 Average r :  37.6
# save weights:  3500 episodes
#  3600/20000 [.....] - ETA: 8:25:01 Average r :  35.0
# save weights:  3600 episodes
#  3700/20000 [.....] - ETA: 8:21:06 Average r :  46.7
# save weights:  3700 episodes
#  3800/20000 [.....] - ETA: 8:17:41 Average r :  37.6
# save weights:  3800 episodes
#  3900/20000 [.....] - ETA: 8:13:02 Average r :  53.2
# save weights:  3900 episodes
#  4000/20000 [>....] - ETA: 8:08:27 Average r :  48.0
# save weights:  4000 episodes
#  4100/20000 [>....] - ETA: 8:04:32 Average r :  38.9
# save weights:  4100 episodes
#  4200/20000 [>....] - ETA: 7:59:42 Average r :  50.6
# save weights:  4200 episodes
#  4300/20000 [>....] - ETA: 7:55:37 Average r :  42.8
# save weights:  4300 episodes
#  4400/20000 [>....] - ETA: 7:50:41 Average r :  57.1
# save weights:  4400 episodes
#  4500/20000 [>....] - ETA: 7:45:18 Average r :  61.0
# save weights:  4500 episodes
#  4600/20000 [>....] - ETA: 7:40:34 Average r :  55.8
# save weights:  4600 episodes
#  4700/20000 [>....] - ETA: 7:36:35 Average r :  50.6
# save weights:  4700 episodes
#  4800/20000 [>....] - ETA: 7:32:17 Average r :  45.4
# save weights:  4800 episodes
#  4900/20000 [>....] - ETA: 7:28:00 Average r :  50.6
# save weights:  4900 episodes
#  5000/20000 [>....] - ETA: 7:24:16 Average r :  38.9
# save weights:  5000 episodes
#  5100/20000 [>....] - ETA: 7:20:15 Average r :  48.0
# save weights:  5100 episodes
#  5200/20000 [>....] - ETA: 7:15:56 Average r :  55.8
# save weights:  5200 episodes
#  5300/20000 [>....] - ETA: 7:12:12 Average r :  51.9
# save weights:  5300 episodes
#  5400/20000 [>....] - ETA: 7:07:38 Average r :  59.7
# save weights:  5400 episodes
#  5500/20000 [>....] - ETA: 7:03:34 Average r :  50.6
# save weights:  5500 episodes
#  5600/20000 [>....] - ETA: 6:59:31 Average r :  58.4
# save weights:  5600 episodes
#  5700/20000 [>....] - ETA: 6:55:20 Average r :  59.7
# save weights:  5700 episodes
#  5800/20000 [>....] - ETA: 6:50:38 Average r :  70.1
# save weights:  5800 episodes
#  5900/20000 [>....] - ETA: 6:46:45 Average r :  53.2
# save weights:  5900 episodes
#  6000/20000 [>....] - ETA: 6:42:55 Average r :  55.8
# save weights:  6000 episodes
#  6100/20000 [>....] - ETA: 6:38:56 Average r :  61.0
# save weights:  6100 episodes
#  6200/20000 [>....] - ETA: 6:35:10 Average r :  61.0
# save weights:  6200 episodes
#  6300/20000 [>....] - ETA: 6:31:23 Average r :  58.4
# save weights:  6300 episodes
#  6400/20000 [>....] - ETA: 6:27:41 Average r :  63.6
# save weights:  6400 episodes
#  6500/20000 [>....] - ETA: 6:23:23 Average r :  70.1
# save weights:  6500 episodes
#  6600/20000 [>....] - ETA: 6:19:24 Average r :  61.0
# save weights:  6600 episodes
#  6700/20000 [>....] - ETA: 6:15:51 Average r :  48.0
# save weights:  6700 episodes
#  6800/20000 [>....] - ETA: 6:12:26 Average r :  54.5
# save weights:  6800 episodes
#  6900/20000 [>....] - ETA: 6:08:51 Average r :  57.1
# save weights:  6900 episodes
#  7000/20000 [>....] - ETA: 6:05:46 Average r :  51.9
# save weights:  7000 episodes
#  7100/20000 [>....] - ETA: 6:02:12 Average r :  57.1
# save weights:  7100 episodes
#  7200/20000 [>....] - ETA: 5:58:41 Average r :  61.0
# save weights:  7200 episodes
#  7300/20000 [>....] - ETA: 5:55:31 Average r :  55.8
# save weights:  7300 episodes
#  7400/20000 [>....] - ETA: 5:52:08 Average r :  58.4
# save weights:  7400 episodes
#  7500/20000 [>....] - ETA: 5:48:20 Average r :  59.7
# save weights:  7500 episodes
#  7600/20000 [>....] - ETA: 5:44:51 Average r :  62.3
# save weights:  7600 episodes
#  7700/20000 [>....] - ETA: 5:41:37 Average r :  53.2
# save weights:  7700 episodes
#  7800/20000 [>....] - ETA: 5:38:25 Average r :  48.0
# save weights:  7800 episodes
#  7900/20000 [>....] - ETA: 5:34:55 Average r :  53.2
# save weights:  7900 episodes
#  8000/20000 [=>...] - ETA: 5:31:16 Average r :  61.0
# save weights:  8000 episodes
#  8100/20000 [=>...] - ETA: 5:27:40 Average r :  61.0
# save weights:  8100 episodes
#  8200/20000 [=>...] - ETA: 5:24:05 Average r :  57.1
# save weights:  8200 episodes
#  8300/20000 [=>...] - ETA: 5:20:20 Average r :  67.5
# save weights:  8300 episodes
#  8400/20000 [=>...] - ETA: 5:16:59 Average r :  55.8
# save weights:  8400 episodes
#  8500/20000 [=>...] - ETA: 5:13:45 Average r :  46.7
# save weights:  8500 episodes
#  8600/20000 [=>...] - ETA: 5:10:19 Average r :  54.5
# save weights:  8600 episodes
#  8700/20000 [=>...] - ETA: 5:06:56 Average r :  58.4
# save weights:  8700 episodes
#  8800/20000 [=>...] - ETA: 5:03:21 Average r :  57.1
# save weights:  8800 episodes
#  8900/20000 [=>...] - ETA: 4:59:41 Average r :  63.6
# save weights:  8900 episodes
#  9000/20000 [=>...] - ETA: 4:56:18 Average r :  58.4
# save weights:  9000 episodes
#  9100/20000 [=>...] - ETA: 4:52:55 Average r :  55.8
# save weights:  9100 episodes
#  9200/20000 [=>...] - ETA: 4:49:39 Average r :  57.1
# save weights:  9200 episodes
#  9300/20000 [=>...] - ETA: 4:46:28 Average r :  49.3
# save weights:  9300 episodes
#  9400/20000 [=>...] - ETA: 4:43:24 Average r :  54.5
# save weights:  9400 episodes
#  9500/20000 [=>...] - ETA: 4:40:14 Average r :  54.5
# save weights:  9500 episodes
#  9600/20000 [=>...] - ETA: 4:36:55 Average r :  57.1
# save weights:  9600 episodes
#  9700/20000 [=>...] - ETA: 4:33:43 Average r :  59.7
# save weights:  9700 episodes
#  9800/20000 [=>...] - ETA: 4:30:34 Average r :  59.7
# save weights:  9800 episodes
#  9900/20000 [=>...] - ETA: 4:27:35 Average r :  48.0
# save weights:  9900 episodes
# 10000/20000 [=>...] - ETA: 4:24:35 Average r :  49.3
# save weights:  10000 episodes
# 10100/20000 [=>...] - ETA: 4:21:25 Average r :  53.2
# save weights:  10100 episodes
# 10200/20000 [=>...] - ETA: 4:18:35 Average r :  33.7
# save weights:  10200 episodes
# 10300/20000 [=>...] - ETA: 4:15:38 Average r :  41.5
# save weights:  10300 episodes
# 10400/20000 [=>...] - ETA: 4:12:42 Average r :  44.1
# save weights:  10400 episodes
# 10500/20000 [=>...] - ETA: 4:10:01 Average r :  29.8
# save weights:  10500 episodes
# 10600/20000 [=>...] - ETA: 4:07:12 Average r :  33.7
# save weights:  10600 episodes
# 10700/20000 [=>...] - ETA: 4:04:23 Average r :  37.6
# save weights:  10700 episodes
# 10800/20000 [=>...] - ETA: 4:01:22 Average r :  41.5
# save weights:  10800 episodes
# 10900/20000 [=>...] - ETA: 3:58:35 Average r :  32.4
# save weights:  10900 episodes
# 11000/20000 [=>...] - ETA: 3:55:59 Average r :  27.2
# save weights:  11000 episodes
# 11100/20000 [=>...] - ETA: 3:53:07 Average r :  32.4
# save weights:  11100 episodes
# 11200/20000 [=>...] - ETA: 3:50:18 Average r :  38.9
# save weights:  11200 episodes
# 11300/20000 [=>...] - ETA: 3:47:19 Average r :  48.0
# save weights:  11300 episodes
# 11400/20000 [=>...] - ETA: 3:44:39 Average r :  28.5
# save weights:  11400 episodes
# 11500/20000 [=>...] - ETA: 3:41:45 Average r :  40.2
# save weights:  11500 episodes
# 11600/20000 [=>...] - ETA: 3:38:59 Average r :  33.7
# save weights:  11600 episodes
# 11700/20000 [=>...] - ETA: 3:36:18 Average r :  29.8
# save weights:  11700 episodes
# 11800/20000 [=>...] - ETA: 3:33:39 Average r :  32.4
# save weights:  11800 episodes
# 11900/20000 [=>...] - ETA: 3:30:54 Average r :  35.0
# save weights:  11900 episodes
# 12000/20000 [==>..] - ETA: 3:28:10 Average r :  33.7
# save weights:  12000 episodes
# 12100/20000 [==>..] - ETA: 3:25:28 Average r :  36.3
# save weights:  12100 episodes
# 12200/20000 [==>..] - ETA: 3:22:50 Average r :  29.8
# save weights:  12200 episodes
# 12300/20000 [==>..] - ETA: 3:20:00 Average r :  38.9
# save weights:  12300 episodes
# 12400/20000 [==>..] - ETA: 3:17:14 Average r :  37.6
# save weights:  12400 episodes
# 12500/20000 [==>..] - ETA: 3:14:27 Average r :  38.9
# save weights:  12500 episodes
# 12600/20000 [==>..] - ETA: 3:11:42 Average r :  38.9
# save weights:  12600 episodes
# 12700/20000 [==>..] - ETA: 3:09:03 Average r :  35.0
# save weights:  12700 episodes
# 12800/20000 [==>..] - ETA: 3:06:27 Average r :  29.8
# save weights:  12800 episodes
# 12900/20000 [==>..] - ETA: 3:03:39 Average r :  46.7
# save weights:  12900 episodes
# 13000/20000 [==>..] - ETA: 3:00:58 Average r :  35.0
# save weights:  13000 episodes
# 13100/20000 [==>..] - ETA: 2:58:15 Average r :  42.8
# save weights:  13100 episodes
# 13200/20000 [==>..] - ETA: 2:55:25 Average r :  50.6
# save weights:  13200 episodes
# 13300/20000 [==>..] - ETA: 2:52:36 Average r :  53.2
# save weights:  13300 episodes
# 13400/20000 [==>..] - ETA: 2:49:52 Average r :  40.2
# save weights:  13400 episodes
# 13500/20000 [==>..] - ETA: 2:47:08 Average r :  45.4
# save weights:  13500 episodes
# 13600/20000 [==>..] - ETA: 2:44:24 Average r :  46.7
# save weights:  13600 episodes
# 13700/20000 [==>..] - ETA: 2:41:44 Average r :  44.1
# save weights:  13700 episodes
# 13800/20000 [==>..] - ETA: 2:38:56 Average r :  54.5
# save weights:  13800 episodes
# 13900/20000 [==>..] - ETA: 2:36:10 Average r :  54.5
# save weights:  13900 episodes
# 14000/20000 [==>..] - ETA: 2:33:23 Average r :  54.5
# save weights:  14000 episodes
# 14100/20000 [==>..] - ETA: 2:30:42 Average r :  46.7
# save weights:  14100 episodes
# 14200/20000 [==>..] - ETA: 2:27:56 Average r :  63.6
# save weights:  14200 episodes
# 14300/20000 [==>..] - ETA: 2:25:07 Average r :  61.0
# save weights:  14300 episodes
# 14400/20000 [==>..] - ETA: 2:22:28 Average r :  46.7
# save weights:  14400 episodes
# 14500/20000 [==>..] - ETA: 2:19:47 Average r :  53.2
# save weights:  14500 episodes
# 14600/20000 [==>..] - ETA: 2:17:07 Average r :  54.5
# save weights:  14600 episodes
# 14699/20000 [==>..] - ETA: 2:14:26 Average r :  61.0
# save weights:  14700 episodes
# 14800/20000 [==>..] - ETA: 2:11:49 Average r :  44.1
# save weights:  14800 episodes
# 14900/20000 [==>..] - ETA: 2:09:06 Average r :  58.4
# save weights:  14900 episodes
# 15000/20000 [==>..] - ETA: 2:06:27 Average r :  51.9
# save weights:  15000 episodes
# 15100/20000 [==>..] - ETA: 2:03:52 Average r :  46.7
# save weights:  15100 episodes
# 15200/20000 [==>..] - ETA: 2:01:13 Average r :  58.4
# save weights:  15200 episodes
# 15300/20000 [==>..] - ETA: 1:58:35 Average r :  50.6
# save weights:  15300 episodes
# 15400/20000 [==>..] - ETA: 1:55:52 Average r :  64.9
# save weights:  15400 episodes
# 15500/20000 [==>..] - ETA: 1:53:14 Average r :  51.9
# save weights:  15500 episodes
# 15600/20000 [==>..] - ETA: 1:50:37 Average r :  55.8
# save weights:  15600 episodes
# 15700/20000 [==>..] - ETA: 1:47:57 Average r :  70.1
# save weights:  15700 episodes
# 15800/20000 [==>..] - ETA: 1:45:15 Average r :  68.8
# save weights:  15800 episodes
# 15900/20000 [==>..] - ETA: 1:42:37 Average r :  63.6
# save weights:  15900 episodes
# 16000/20000 [===>.] - ETA: 1:40:03 Average r :  57.1
# save weights:  16000 episodes
# 16100/20000 [===>.] - ETA: 1:37:31 Average r :  55.8
# save weights:  16100 episodes
# 16200/20000 [===>.] - ETA: 1:34:57 Average r :  59.7
# save weights:  16200 episodes
# 16300/20000 [===>.] - ETA: 1:32:21 Average r :  66.2
# save weights:  16300 episodes
# 16400/20000 [===>.] - ETA: 1:29:48 Average r :  62.3
# save weights:  16400 episodes
# 16500/20000 [===>.] - ETA: 1:27:12 Average r :  66.2
# save weights:  16500 episodes
# 16600/20000 [===>.] - ETA: 1:24:38 Average r :  68.8
# save weights:  16600 episodes
# 16700/20000 [===>.] - ETA: 1:22:01 Average r :  68.8
# save weights:  16700 episodes
# 16800/20000 [===>.] - ETA: 1:19:29 Average r :  57.1
# save weights:  16800 episodes
# 16900/20000 [===>.] - ETA: 1:16:54 Average r :  66.2
# save weights:  16900 episodes
# 17000/20000 [===>.] - ETA: 1:14:19 Average r :  63.6
# save weights:  17000 episodes
# 17100/20000 [===>.] - ETA: 1:11:46 Average r :  62.3
# save weights:  17100 episodes
# 17200/20000 [===>.] - ETA: 1:09:08 Average r :  80.5
# save weights:  17200 episodes
# 17300/20000 [===>.] - ETA: 1:06:35 Average r :  66.2
# save weights:  17300 episodes
# 17400/20000 [===>.] - ETA: 1:04:06 Average r :  54.5
# save weights:  17400 episodes
# 17500/20000 [===>.] - ETA: 1:01:33 Average r :  74.0
# save weights:  17500 episodes
# 17600/20000 [===>.] - ETA: 59:03 Average r :  59.7
# save weights:  17600 episodes
# 17700/20000 [===>.] - ETA: 56:32 Average r :  67.5
# save weights:  17700 episodes
# 17800/20000 [===>.] - ETA: 54:02 Average r :  72.7
# save weights:  17800 episodes
# 17900/20000 [===>.] - ETA: 51:32 Average r :  68.8
# save weights:  17900 episodes
# 18000/20000 [===>.] - ETA: 49:02 Average r :  70.1
# save weights:  18000 episodes
# 18100/20000 [===>.] - ETA: 46:32 Average r :  61.0
# save weights:  18100 episodes
# 18200/20000 [===>.] - ETA: 44:04 Average r :  51.9
# save weights:  18200 episodes
# 18300/20000 [===>.] - ETA: 41:34 Average r :  63.6
# save weights:  18300 episodes
# 18400/20000 [===>.] - ETA: 39:06 Average r :  64.9
# save weights:  18400 episodes
# 18500/20000 [===>.] - ETA: 36:37 Average r :  58.4
# save weights:  18500 episodes
# 18600/20000 [===>.] - ETA: 34:09 Average r :  61.0
# save weights:  18600 episodes
# 18700/20000 [===>.] - ETA: 31:41 Average r :  61.0
# save weights:  18700 episodes
# 18800/20000 [===>.] - ETA: 29:13 Average r :  61.0
# save weights:  18800 episodes
# 18900/20000 [===>.] - ETA: 26:44 Average r :  70.1
# save weights:  18900 episodes
# 19000/20000 [===>.] - ETA: 24:17 Average r :  61.0
# save weights:  19000 episodes
# 19087/20000 [===>.] - ETA: 22:09

# %%
# %%javascript
# Jupyter.notebook.session.delete();
