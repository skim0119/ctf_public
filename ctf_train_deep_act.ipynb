# %% [markdown]
# # Capture the Flag (RL - Policy Gradient)
#
# - Seung Hyun Kim
# - skim449@illinois.edu
#
# ## Notes
# - This notebook includes:
#     - Building the structure of policy driven network.
#     - Training with/without render
#     - Saver that save model and weights to ./model directory
#     - Writer that will record some necessary datas to ./logs
# - This notebook does not include running the CtF game with the RL policy. Using the network will be separately scripted in policy/policy_RL1.py.
#     - cap_test.py is changed appropriately.
#
# ## References :
# - https://github.com/awjuliani/DeepRL-Agents/blob/master/Vanilla-Policy.ipynb (source)
# - https://www.youtube.com/watch?v=PDbXPBwOavc

# %%
TRAIN_NAME='NO_RED_03_ACT'
LOG_PATH='./logs/'+TRAIN_NAME
MODEL_PATH='./model/' + TRAIN_NAME
GPU_CAPACITY=0.5 # gpu capacity in percentage

# %%
import os

import tensorflow as tf
import tensorflow.contrib.slim as slim
import matplotlib.pyplot as plt
# %matplotlib inline

import time
import gym
import gym_cap
import gym_cap.envs.const as CONST
import numpy as np
import random

# the modules that you can use to generate the policy.
import policy.patrol 
import policy.random
import policy.simple # custon written policy
import policy.policy_RL
import policy.zeros
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
if not os.path.exists(MODEL_PATH):
    os.makedirs(MODEL_PATH)
    
#Create a directory to save episode playback gifs to
if not os.path.exists(LOG_PATH):
    os.makedirs(LOG_PATH)

# %% [markdown]
# ## Environment Setting

# %%
env = gym.make("cap-v0") # initialize the environment
policy_red = policy.random.PolicyGen(env.get_map, env.get_team_red)

UNKNOWN  = CONST.UNKNOWN # -1
TEAM1_BG = CONST.TEAM1_BACKGROUND # 0
TEAM2_BG = CONST.TEAM2_BACKGROUND # 1
TEAM1_AG = CONST.TEAM1_UGV # 2
TEAM2_AG = CONST.TEAM2_UGV # 4
TEAM1_FL = CONST.TEAM1_FLAG # 6
TEAM2_FL = CONST.TEAM2_FLAG # 7
OBSTACLE = CONST.OBSTACLE # 8
DEAD     = CONST.DEAD # 9
SELECTED = CONST.SELECTED # 10
COMPLETED= CONST.COMPLETED # 11

VISION_RANGE = 10 #CONST.UGV_RANGE
VISION_dX    = 2*VISION_RANGE+1
VISION_dY    = 2*VISION_RANGE+1

# %%
print('red number : ', len(env.get_team_red))
print('blue number : ', len(env.get_team_blue))
print('vision range : ', VISION_RANGE)
# Out:
# red number :  0
# blue number :  4
# vision range :  10

# %% [markdown]
# ## Discount Reward

# %%
gamma = 0.98

def discount_rewards(r, pre_discount=0):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0.0
    pre_disc_factor = gamma**pre_discount
    for t in reversed(range(r.size)):
        running_add = (running_add * gamma + r[t]) * pre_disc_factor
        discounted_r[t] = running_add
    #discounted_r = (discounted_r - np.mean(discounted_r)) / (np.std(discounted_r)+1e-8) # normalize
    #print(discounted_r)
    return discounted_r

def discount_rewards_multiagent(r, n_agents):
    discounted_r = np.reshape(r,(-1,n_agents)) # Reshape the r into vertical matrix with 'n_agents' columns
    for idx in range(n_agents):
        column = discounted_r[:,idx]                     # extract single column
        discounted_r[:,idx] = discount_rewards(column);  # Run discount_reward on the column, and substitute
    return np.reshape(discounted_r,(-1))                 # return the flattened matrix

# %% [markdown]
# ## Network Setting

# %%
class agent():
    def __init__(self, lr, in_size,action_size):
        #These lines established the feed-forward part of the network. The agent takes a state and produces an action.
        self.state_input = tf.placeholder(shape=in_size,dtype=tf.float32, name='state')
        
        layer = slim.conv2d(self.state_input, 16, [5,5], activation_fn=tf.nn.relu,
                            padding='SAME',
                            scope='conv1')
        layer = slim.avg_pool2d(layer, [2,2])
        layer = slim.conv2d(layer, 16, [3,3], activation_fn=tf.nn.relu,
                            padding='SAME',
                            scope='conv2')
        layer = slim.flatten(layer)
        #flat  = tf.reshape(conv, [-1, VISION_dX*VISION_dY*128])
        layer = slim.dropout(layer,keep_prob=0.8)
        layer = slim.fully_connected(layer, 516,
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=None,
                                    scope='hidden_fc1')
        layer = slim.dropout(layer,keep_prob=0.8)
        layer = slim.fully_connected(layer, 516,
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=None)
        self.dense = slim.fully_connected(layer, action_size,
                                    activation_fn=tf.nn.relu,
                                    biases_initializer=None,
                                    scope='output_fc')
        self.output = tf.nn.softmax(self.dense, name='action')
        
        tf.summary.histogram('output', self.output)
        
        with tf.name_scope('weights'):
            for var in slim.get_model_variables():
                tf.summary.histogram(var.op.name, var)

        #The next six lines establish the training proceedure. We feed the reward and chosen action into the network
        #to compute the loss, and use it to update the network.

        with tf.name_scope('Records'):
            self.mean_reward = tf.placeholder("float", None)
            self.mean_length = tf.placeholder("float", None)
            self.mean_succeed = tf.placeholder("float", None)
            #self.mean_stdaction = tf.placeholder("float",None)
            tf.summary.scalar('mean_reward', self.mean_reward)
            tf.summary.scalar('mean_length', self.mean_length)
            tf.summary.scalar('mean_succeed', self.mean_succeed)
    
        with tf.name_scope('action_placement'):
            self.action_holder = tf.placeholder(shape=[None],dtype=tf.int32)
            self.indexes = tf.range(0, tf.shape(self.output)[0]) * tf.shape(self.output)[1] + self.action_holder

        with tf.name_scope('loss'):
            self.reward_holder = tf.placeholder(shape=[None],dtype=tf.float32)
            self.responsible_outputs = tf.gather(tf.reshape(self.output, [-1]), self.indexes)
            self.loss = -tf.reduce_mean(tf.log(self.responsible_outputs)*self.reward_holder)

        tvars = tf.trainable_variables()
        self.gradient_holders = []
        for idx,var in enumerate(tvars):
            placeholder = tf.placeholder(tf.float32,name=str(idx)+'_holder')
            self.gradient_holders.append(placeholder)
        
        with tf.name_scope('gradients'):
            self.gradients = tf.gradients(self.loss,tvars)

        with tf.name_scope('optimizer'):
            optimizer = tf.train.AdamOptimizer(learning_rate=lr)
            self.update_batch = optimizer.apply_gradients(zip(self.gradient_holders,tvars))

# %%
tf.reset_default_graph() # Clear the Tensorflow graph.
myAgent = agent(lr=1e-5,in_size=[None,VISION_dX,VISION_dY,6],action_size=5) #Load the agent.
global_step = tf.Variable(0, trainable=False, name='global_step') # global step
increment_global_step_op = tf.assign(global_step, global_step+1)
merged = tf.summary.merge_all()
# Out:
# /home/namsong/.local/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# ## Hyperparameters

# %%
total_episodes = 10000 #Set total number of episodes to train agent on.
max_ep = 150
update_frequency = 10
save_network_frequency = 100
save_reward_frequency = 10
batch_size = 2000

action_space = 5
n_agent = len(env.get_team_blue)

# %% [markdown]
# ## One-hot Encoder

# %%
def one_hot_encoder(state, agents):
    ret = np.zeros((len(agents),VISION_dX,VISION_dY,6))
    # team 1 : (1), team 2 : (-1), map elements: (0)
    map_channel = {UNKNOWN:0, DEAD:0,
                   TEAM1_BG:1, TEAM2_BG:1,
                   TEAM1_AG:2, TEAM2_AG:2,
                   3:3, 5:3, # UAV, does not need to be included for now
                   TEAM1_FL:4, TEAM2_FL:4,
                   OBSTACLE:5}
    map_color   = {UNKNOWN:1, DEAD:0, OBSTACLE:1,
                   TEAM1_BG:1, TEAM2_BG:-1,
                   TEAM1_AG:1, TEAM2_AG:-1,
                   3:1, 5:-1, # UAV, does not need to be included for now
                   TEAM1_FL:1, TEAM2_FL:-1}
    
    # Expand the observation with 3-thickness wall
    # - in order to avoid dealing with the boundary
    sx, sy = state.shape
    _state = np.ones((sx+2*VISION_RANGE, sy+2*VISION_RANGE)) * OBSTACLE # 8 for obstacle
    _state[VISION_RANGE:VISION_RANGE+sx, VISION_RANGE:VISION_RANGE+sy] = state
    state = _state

    for idx,agent in enumerate(agents):
        # Initialize Variables
        x, y = agent.get_loc()
        x += VISION_RANGE
        y += VISION_RANGE
        vision = state[x-VISION_RANGE:x+VISION_RANGE+1,y-VISION_RANGE:y+VISION_RANGE+1] # extract the limited view for the agent (5x5)
        for i in range(len(vision)):
            for j in range(len(vision[0])):
                if vision[i][j] != -1:
                    channel = map_channel[vision[i][j]]
                    ret[idx][i][j][channel] = map_color[vision[i][j]]
    return ret

# %% [markdown]
# ## Session

# %%
# Launch the session
# Launch the session
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=GPU_CAPACITY)

sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
#sess = tf.Session()

total_reward = []
total_length = []
total_captured = []

# Setup Save and Restore Network
saver = tf.train.Saver(tf.global_variables())
writer = tf.summary.FileWriter(LOG_PATH, sess.graph)

ckpt = tf.train.get_checkpoint_state(MODEL_PATH)
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    saver.restore(sess, ckpt.model_checkpoint_path)
    print("Load Model : ", ckpt.model_checkpoint_path)
else:
    sess.run(tf.global_variables_initializer())
    print("Initialized Variables")
# Out:
# Initialized Variables

# %%
def record(obs):
    feed_dict = {myAgent.mean_reward:np.mean(total_reward[-save_reward_frequency:]),
                         myAgent.mean_length:np.mean(total_length[-save_reward_frequency:]),
                         myAgent.mean_succeed:np.mean(total_captured[-save_reward_frequency:]),
                         myAgent.state_input:obs
                }
    with tf.device('/cpu:0'):    
        summary_str = sess.run(merged, feed_dict=feed_dict)
        writer.add_summary(summary_str, sess.run(global_step))

# %%
gradBuffer = sess.run(tf.trainable_variables())
def clear_buffer():
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0 #np.zeros(grad.shape)

# %%
class Experience_buffer():
    def __init__(self, buffer_size = 30000):
        self.buffer = []
        self.buffer_size = buffer_size
    
    def add(self,experience):
        if len(self.buffer) + len(experience) >= self.buffer_size:
            self.buffer[0:(len(experience)+len(self.buffer))-self.buffer_size] = []
        self.buffer.extend(experience)
            
    def sample(self, size=2000):
        if size > len(self.buffer):
            return np.array(self.buffer)
        else:
            return np.reshape(np.array(random.sample(self.buffer,size)),[size,3])

# %%
def policy_rollout(env, explore=False):
    # Run single episode, return the results (number of frame, history, total reward, game_won, last obs)
    s = env.reset(map_size=20, policy_red=policy_red)
    ep_history = []
    indv_history = [[] for _ in range(len(env.get_team_blue))]
    
    was_alive = [ag.isAlive for ag in env.get_team_blue]
    prev_reward=0
    for frame in range(max_ep+1):
        #obs = one_hot_encoder(s, env.get_team_blue).tolist() # partial observation
        obs = one_hot_encoder(env._env, env.get_team_blue) # Full observation
        
        if explore:
            act = np.random.randint(action_space, size=n_agent).tolist()
        else:
            with tf.device('/cpu:0'):        
                #Probabilistically pick an action given our network outputs.
                act_prob = sess.run(myAgent.output, feed_dict={myAgent.state_input:obs})
                act = [np.random.choice(action_space, p=act_prob[x]/sum(act_prob[x])) for x in range(n_agent)] # divide by sum : normalize
            
        s,r,d,_ = env.step(act) #Get our reward for taking an action given a bandit.
        
        # If frame is at max and the game is still not done, negative reward
        if frame == max_ep and d == False:
            r -= 30
            
        # Push history for individual that 'was' alive previous frame
        for idx, agent in enumerate(env.get_team_blue):
            if was_alive[idx]: indv_history[idx].append([obs[idx],act[idx],r])

        # If reward sequence change, push the history into the episode history.
        if prev_reward != r:
            for idx, history in enumerate(indv_history):
                if len(history)==0: continue
                if not was_alive[idx]: continue
                _history = np.array(history)
                _history[:,2] = discount_rewards(_history[:,2])
                ep_history.extend(_history)
        
        # State Transition
        frame += 1
        prev_reward = r
        was_alive = [ag.isAlive for ag in env.get_team_blue]
        
        if d == True:
            break
    if len(ep_history) > 0:        
        ep_history = np.stack(ep_history)
    
    return [frame, ep_history, r, env.game_won, obs]

# %% [markdown]
# ## Training

# %%
ep = 0

exploration_count = 20
exp_buffer = Experience_buffer()
clear_buffer()
try:
    progbar = tf.keras.utils.Progbar(total_episodes,width=5)
    while ep < total_episodes+1:
        progbar.update(ep) # update progress bar
         
        # Run episode
        frame, history, reward, did_won, obs = policy_rollout(env, exploration_count > ep)
        
        # Add history
        exp_buffer.add(history)

        if exploration_count < ep:
            with tf.device('/gpu:0'):
                batch_history = exp_buffer.sample(batch_size) # Sample from experience replay
                feed_dict={myAgent.reward_holder:batch_history[:,2],
                           myAgent.action_holder:batch_history[:,1],
                           myAgent.state_input:np.stack(batch_history[:,0])}
                grads = sess.run(myAgent.gradients, feed_dict=feed_dict)

                for idx,grad in enumerate(grads):
                    gradBuffer[idx] += grad
                if ep % update_frequency == 0 and ep != 0:
                    feed_dict= dictionary = dict(zip(myAgent.gradient_holders, gradBuffer))
                    with tf.device('/gpu:0'):
                        _ = sess.run(myAgent.update_batch, feed_dict=feed_dict)
                    clear_buffer()

        total_reward.append(reward)
        total_length.append(frame)
        total_captured.append(env.game_won)
        if ep % save_reward_frequency == 0 and ep != 0:
            record(obs)
        
        # save every 100 ep
        if ep % save_network_frequency == 0 and ep != 0:
            print(' Average r : ', np.mean(total_reward[-save_network_frequency:]))
            saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
            print("save weights: ", sess.run(global_step), 'episodes')

        ep += 1
        sess.run(increment_global_step_op)
        
except KeyboardInterrupt:
    print('\n\nManually stopped the training (KeyboardInterrupt)');
    plt.plot(total_reward)
    plt.figure()
    plt.plot(total_length)
    plt.figure()
    plt.plot(total_captured)
    saver.save(sess, MODEL_PATH+'/ctf_policy.ckpt', global_step=global_step)
    record(obs)
    print("save: ", sess.run(global_step), 'episodes')
# Out:
#   100/10000 [.....] - ETA: 5:34:24 Average r :  -7.9
# save weights:  100 episodes
#   200/10000 [.....] - ETA: 5:35:31 Average r :  -11.8
# save weights:  200 episodes
#   300/10000 [.....] - ETA: 5:35:21 Average r :  -6.6
# save weights:  300 episodes
#   400/10000 [.....] - ETA: 5:31:33 Average r :  -1.4
# save weights:  400 episodes
#   500/10000 [.....] - ETA: 5:24:04 Average r :  19.4
# save weights:  500 episodes
#   600/10000 [.....] - ETA: 5:16:40 Average r :  20.7
# save weights:  600 episodes
#   700/10000 [.....] - ETA: 5:09:22 Average r :  22.0
# save weights:  700 episodes
#   800/10000 [.....] - ETA: 5:03:18 Average r :  25.9
# save weights:  800 episodes
#   900/10000 [.....] - ETA: 4:59:17 Average r :  20.7
# save weights:  900 episodes
#  1000/10000 [.....] - ETA: 4:55:18 Average r :  20.7
# save weights:  1000 episodes
#  1100/10000 [.....] - ETA: 4:50:03 Average r :  24.6
# save weights:  1100 episodes
#  1200/10000 [.....] - ETA: 4:44:23 Average r :  29.8
# save weights:  1200 episodes
#  1300/10000 [.....] - ETA: 4:38:56 Average r :  37.6
# save weights:  1300 episodes
#  1400/10000 [.....] - ETA: 4:32:39 Average r :  42.8
# save weights:  1400 episodes
#  1500/10000 [.....] - ETA: 4:27:51 Average r :  40.2
# save weights:  1500 episodes
#  1600/10000 [.....] - ETA: 4:22:02 Average r :  41.5
# save weights:  1600 episodes
#  1700/10000 [.....] - ETA: 4:18:04 Average r :  36.3
# save weights:  1700 episodes
#  1800/10000 [.....] - ETA: 4:14:01 Average r :  33.7
# save weights:  1800 episodes
#  1900/10000 [.....] - ETA: 4:10:30 Average r :  28.5
# save weights:  1900 episodes
#  2000/10000 [>....] - ETA: 4:06:34 Average r :  35.0
# save weights:  2000 episodes
#  2100/10000 [>....] - ETA: 4:02:14 Average r :  36.3
# save weights:  2100 episodes
#  2200/10000 [>....] - ETA: 3:58:48 Average r :  35.0
# save weights:  2200 episodes
#  2300/10000 [>....] - ETA: 3:54:42 Average r :  42.8
# save weights:  2300 episodes
#  2400/10000 [>....] - ETA: 3:50:53 Average r :  37.6
# save weights:  2400 episodes
#  2500/10000 [>....] - ETA: 3:47:47 Average r :  32.4
# save weights:  2500 episodes
#  2600/10000 [>....] - ETA: 3:44:01 Average r :  48.0
# save weights:  2600 episodes
#  2700/10000 [>....] - ETA: 3:40:24 Average r :  37.6
# save weights:  2700 episodes
#  2800/10000 [>....] - ETA: 3:36:59 Average r :  40.2
# save weights:  2800 episodes
#  2900/10000 [>....] - ETA: 3:33:29 Average r :  41.5
# save weights:  2900 episodes
#  3000/10000 [>....] - ETA: 3:29:34 Average r :  42.8
# save weights:  3000 episodes
#  3100/10000 [>....] - ETA: 3:26:05 Average r :  35.0
# save weights:  3100 episodes
#  3200/10000 [>....] - ETA: 3:22:32 Average r :  42.8
# save weights:  3200 episodes
#  3300/10000 [>....] - ETA: 3:19:06 Average r :  41.5
# save weights:  3300 episodes
#  3400/10000 [>....] - ETA: 3:15:46 Average r :  35.0
# save weights:  3400 episodes
#  3500/10000 [>....] - ETA: 3:12:42 Average r :  32.4
# save weights:  3500 episodes
#  3600/10000 [>....] - ETA: 3:09:35 Average r :  42.8
# save weights:  3600 episodes
#  3700/10000 [>....] - ETA: 3:06:10 Average r :  48.0
# save weights:  3700 episodes
#  3800/10000 [>....] - ETA: 3:03:05 Average r :  40.2
# save weights:  3800 episodes
#  3900/10000 [>....] - ETA: 2:59:48 Average r :  40.2
# save weights:  3900 episodes
#  4000/10000 [=>...] - ETA: 2:56:41 Average r :  32.4
# save weights:  4000 episodes
#  4100/10000 [=>...] - ETA: 2:53:28 Average r :  27.2
# save weights:  4100 episodes
#  4200/10000 [=>...] - ETA: 2:50:14 Average r :  41.5
# save weights:  4200 episodes
#  4300/10000 [=>...] - ETA: 2:47:17 Average r :  31.1
# save weights:  4300 episodes
#  4400/10000 [=>...] - ETA: 2:43:48 Average r :  51.9
# save weights:  4400 episodes
#  4500/10000 [=>...] - ETA: 2:40:19 Average r :  50.6
# save weights:  4500 episodes
#  4600/10000 [=>...] - ETA: 2:36:56 Average r :  44.1
# save weights:  4600 episodes
#  4700/10000 [=>...] - ETA: 2:33:49 Average r :  37.6
# save weights:  4700 episodes
#  4800/10000 [=>...] - ETA: 2:30:33 Average r :  44.1
# save weights:  4800 episodes
#  4900/10000 [=>...] - ETA: 2:27:26 Average r :  38.9
# save weights:  4900 episodes
#  5000/10000 [=>...] - ETA: 2:24:14 Average r :  53.2
# save weights:  5000 episodes
#  5100/10000 [=>...] - ETA: 2:20:58 Average r :  45.4
# save weights:  5100 episodes
#  5200/10000 [=>...] - ETA: 2:18:02 Average r :  35.0
# save weights:  5200 episodes
#  5300/10000 [=>...] - ETA: 2:15:12 Average r :  24.6
# save weights:  5300 episodes
#  5400/10000 [=>...] - ETA: 2:12:07 Average r :  50.6
# save weights:  5400 episodes
#  5500/10000 [=>...] - ETA: 2:09:07 Average r :  42.8
# save weights:  5500 episodes
#  5600/10000 [=>...] - ETA: 2:06:01 Average r :  51.9
# save weights:  5600 episodes
#  5700/10000 [=>...] - ETA: 2:03:02 Average r :  40.2
# save weights:  5700 episodes
#  5800/10000 [=>...] - ETA: 2:00:06 Average r :  33.7
# save weights:  5800 episodes
#  5900/10000 [=>...] - ETA: 1:57:13 Average r :  36.3
# save weights:  5900 episodes
#  6000/10000 [==>..] - ETA: 1:54:16 Average r :  41.5
# save weights:  6000 episodes
#  6100/10000 [==>..] - ETA: 1:51:18 Average r :  44.1
# save weights:  6100 episodes
#  6200/10000 [==>..] - ETA: 1:48:26 Average r :  33.7
# save weights:  6200 episodes
#  6300/10000 [==>..] - ETA: 1:45:33 Average r :  36.3
# save weights:  6300 episodes
#  6400/10000 [==>..] - ETA: 1:42:42 Average r :  29.8
# save weights:  6400 episodes
#  6500/10000 [==>..] - ETA: 1:39:45 Average r :  40.2
# save weights:  6500 episodes
#  6600/10000 [==>..] - ETA: 1:36:46 Average r :  44.1
# save weights:  6600 episodes
#  6700/10000 [==>..] - ETA: 1:33:46 Average r :  53.2
# save weights:  6700 episodes
#  6800/10000 [==>..] - ETA: 1:30:49 Average r :  48.0
# save weights:  6800 episodes
#  6900/10000 [==>..] - ETA: 1:27:50 Average r :  49.3
# save weights:  6900 episodes
#  7000/10000 [==>..] - ETA: 1:24:54 Average r :  51.9
# save weights:  7000 episodes
#  7100/10000 [==>..] - ETA: 1:21:59 Average r :  44.1
# save weights:  7100 episodes
#  7200/10000 [==>..] - ETA: 1:19:08 Average r :  40.2
# save weights:  7200 episodes
#  7300/10000 [==>..] - ETA: 1:16:15 Average r :  45.4
# save weights:  7300 episodes
#  7400/10000 [==>..] - ETA: 1:13:24 Average r :  42.8
# save weights:  7400 episodes
#  7500/10000 [==>..] - ETA: 1:10:29 Average r :  49.3
# save weights:  7500 episodes
#  7600/10000 [==>..] - ETA: 1:07:39 Average r :  44.1
# save weights:  7600 episodes
#  7700/10000 [==>..] - ETA: 1:04:45 Average r :  48.0
# save weights:  7700 episodes
#  7800/10000 [==>..] - ETA: 1:01:58 Average r :  29.8
# save weights:  7800 episodes
#  7900/10000 [==>..] - ETA: 59:09 Average r :  38.9
# save weights:  7900 episodes
#  8100/10000 [===>.] - ETA: 53:24 Average r :  45.4
# save weights:  8100 episodes
#  8200/10000 [===>.] - ETA: 50:32 Average r :  53.2
# save weights:  8200 episodes
#  8300/10000 [===>.] - ETA: 47:41 Average r :  41.5
# save weights:  8300 episodes
#  8400/10000 [===>.] - ETA: 44:52 Average r :  32.4
# save weights:  8400 episodes
#  8500/10000 [===>.] - ETA: 42:03 Average r :  41.5
# save weights:  8500 episodes
#  8600/10000 [===>.] - ETA: 39:13 Average r :  42.8
# save weights:  8600 episodes
#  8700/10000 [===>.] - ETA: 36:24 Average r :  42.8
# save weights:  8700 episodes
#  8800/10000 [===>.] - ETA: 33:34 Average r :  42.8
# save weights:  8800 episodes
#  8900/10000 [===>.] - ETA: 30:45 Average r :  50.6
# save weights:  8900 episodes
#  9000/10000 [===>.] - ETA: 27:56 Average r :  46.7
# save weights:  9000 episodes
#  9100/10000 [===>.] - ETA: 25:08 Average r :  35.0
# save weights:  9100 episodes
#  9200/10000 [===>.] - ETA: 22:18 Average r :  55.8
# save weights:  9200 episodes
#  9300/10000 [===>.] - ETA: 19:31 Average r :  32.4
# save weights:  9300 episodes
#  9400/10000 [===>.] - ETA: 16:43 Average r :  38.9
# save weights:  9400 episodes
#  9500/10000 [===>.] - ETA: 13:55 Average r :  53.2
# save weights:  9500 episodes
#  9600/10000 [===>.] - ETA: 11:07 Average r :  44.1
# save weights:  9600 episodes
#  9700/10000 [===>.] - ETA: 8:20 Average r :  44.1
# save weights:  9700 episodes
#  9800/10000 [===>.] - ETA: 5:33 Average r :  46.7
# save weights:  9800 episodes
#  9900/10000 [===>.] - ETA: 2:46 Average r :  37.6
# save weights:  9900 episodes
# 10000/10000 [=====] - 16683s 2s/step
#  Average r :  42.8
# save weights:  10000 episodes
